# %% [markdown]
# # Module 5: Data Collection & Cleaning Part 1

# %% [markdown]
# # Introduction
#
# Collecting and cleaning data is the key topic discussed in this module. We will continue working with `pandas` and  focus on the process for cleaning web data.
#
# Our emphasis will be on extraction, transformation and loading methods. This module consists of 3 parts.
#
# - **Part 1** - Data Sources
# - **Part 2** - Web Scraping
# - **Part 3** - Data Preparation
#
# Each part is provided in a separate file. It is recommended that you follow the order of the files.

# %% [markdown]
# # Learning Outcomes
#
# In this module, we cover the following using Python libraries for gathering and preparing data:
#
# * Discuss types of data
# * Process data from the web
# * Clean up bad data using `pandas`
# * Handle missing data

# %% [markdown]
# # Readings and Resources
#
# The majority of the notebook draws from the recommended readings. We invite you to further supplement this notebook with the following recommended texts.
#
# McKinney, W. (2017). Python for data analysis: Data wrangling with Pandas, NumPy, and IPython (2nd Ed.). O'Reilly Media.
#   * Ch. 6 (p 167-178, 186-187)
#   * Ch. 7 (p. 191-213)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <br>
# <div class="toc">
# <ul class="toc-item">
# <li><span><a href="#Module-5:-Data-Collection-&-Cleaning-Part-1" data-toc-modified-id="Module-5:-Data-Collection-&-Cleaning-Part-1">Module 5: Data Collection & Cleaning Part 1</a></span>
# </li>
# <li><span><a href="#Introduction" data-toc-modified-id="Introduction">Introduction</a></span>
# </li>
# <li><span><a href="#Learning-Outcomes" data-toc-modified-id="Learning-Outcomes">Learning Outcomes</a></span>
# </li>
# <li><span><a href="#Readings-and-Resources" data-toc-modified-id="Readings-and-Resources">Readings and Resources</a></span>
# </li>
# <li><span><a href="#Table-of-Contents" data-toc-modified-id="Table-of-Contents">Table of Contents</a></span>
# </li>
# <li><span><a href="#Preparing-the-Data:-Importing-and-Cleaning-Data" data-toc-modified-id="Preparing-the-Data:-Importing-and-Cleaning-Data">Preparing the Data: Importing and Cleaning Data</a></span>
# </li>
# <li><span><a href="#Data-Sources" data-toc-modified-id="Data-Sources">Data Sources</a></span>
# <ul class="toc-item">
# <li><span><a href="#Types-of-Websites" data-toc-modified-id="Types-of-Websites">Types of Websites</a></span>
# </li>
# <li><span><a href="#Web-Page-Contents" data-toc-modified-id="Web-Page-Contents">Web Page Contents</a></span>
# <ul class="toc-item">
# <li><span><a href="#HTML" data-toc-modified-id="HTML">HTML</a></span>
# </li>
# <li><span><a href="#XML" data-toc-modified-id="XML">XML</a></span>
# </li>
# <li><span><a href="#CSS" data-toc-modified-id="CSS">CSS</a></span>
# </li>
# <li><span><a href="#JavaScript" data-toc-modified-id="JavaScript">JavaScript</a></span>
# </li>
# <li><span><a href="#Semantic-Web-Content" data-toc-modified-id="Semantic-Web-Content">Semantic Web Content</a></span>
# </li>
# <li><span><a href="#Images" data-toc-modified-id="Images">Images</a></span>
# </li>
# <li><span><a href="#Micro-formats" data-toc-modified-id="Micro-formats">Micro-formats</a></span>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li><span><a href="#References" data-toc-modified-id="References">References</a></span>
# </li>
# </ul>
# </div>

# %% [markdown]
# # Preparing the Data: Importing and Cleaning Data

# %% [markdown]
# <figure>
#     <img src="dataScienceProcess.png" alt="This image shows the stages of creating a model from start to finish." style="width: 100%;"> (Course Authors, 2018)
#     <figcaption><em>This image shows the stages of creating a model from start to finish.</em></figcaption>
# </figure>
#
# Now that you have learned some basic functions of Python, we will begin exploring real data sources. When you clearly define your business problem, you should consider what data may be required to solve it. During this phase of the analytics methodology, you should &mdash; within the boundaries of your organizational policies &mdash; collect all data points that you think are relevant to your problem. This includes internal or external data.
#
# Once you have the data points that may be relevant, you should conduct preliminary reviews of the data to answer some of the following questions:
#
# - Is the data set complete?
# - Is it accurate? Reliable?
# - Is it biased?
# - Is there enough data to draw significant conclusions about the problem?
#
# You can address these questions by leveraging basic functions in NumPy and Pandas to organize and understand your data set.
#
# Once you have narrowed down the data points you need, the next step is to cleanse the data such that it is consistent and usable for your analysis. In this module, we will first learn how to access data from a variety of external data sources (for example, websites), and then how to clean the data. Once the data is clean, we will be able to move on to the analysis and model development phases.

# %% [markdown]
# # Data Sources

# %% [markdown]
# In recent years, many websites have made available public Application Programming Interfaces (APIs) providing data feeds (Motto, 2018). Web and Software development standards have forced a shift in the way these API's deliver data. Originally there was no standard, but with the formation of the World Wide Web Consortium (W3C) (W3C, 2018) many web technologies became standardized.
#
# The first major shift in web development practices came with Web 2.0 (Web 2.0, nd), where web client-side technologies (i.e., what runs in your browser) were separated by concerns. What was originally only HyperText Markup Language (HTML) (WC3 Community, 2018) was split off into three main technologies:
#
# 1. **Extensible Markup Language (XML)** (W3C Community, 2016) (*content and metadata*)
#
#
# 2. **Style Sheets** (Bos, 2018) (*for typography or formatting*)
#   * The most well recognized technology being **Cascading Style Sheets (CSS)** (Mozilla and individual contributors, 2018)
#
#
# 3. **Client-Side JavaScript** (Hazaël-Massieux, 2016)
#
# The second major shift came in the mid 2000's, when web technologies began standardization for Web 3.0 (*a.k.a. The Semantic Web*) (Semantic Web, nd). The main distinction between Web 3.0 and 2.0 is the separation of content (i.e. XML) from data (i.e. RDF, OWL, JSON-LD). The main technologies of Web 3.0 allow resources to be fully queryable. In other words, the shift to the semantic-web is what helped push the technology sector to become data-driven. Unfortunately, the semantic web did not pan out as once intended. The original vision of the semantic web was to decentralize data and treat the internet as a database. While the technology is in use by major companies (Schema.org community, 2018), cloud-computing and Big-Data technologies alleviated many of the problems the semantic web aimed to solve.
#
# As of 2018, the major use of semantic web technologies is to leverage wikis to become sources of data. While this may not seem like an impressive use case, it is the necessary technology that drives IBM Watson, which was originally a centralized data source reliant entirely on querying semantic-web-enabled wikis to further increment its knowledge graph, and to intelligently query the graph to answer questions. As of 2018, the semantic-web stack and its use in IBM Watson is the most impressive example of automated *Data Cleaning* to date.
#
# A similar trend has occurred for web applications. Web 2.0 was the standard for distinguishing web applications from regular websites. The emergence of web applications gave a new way to deliver Software-As-A-Service (SaaS) (Software as a Service, nd), with web applications now being the most popular delivery method. With the arrival of cloud-computing, SaaS became the standard for delivering information technology products. In this process, distribution of software became an increasing concern, leading to adoption of decentralized software architectures. The main pattern in use as of 2018 is that of Micro-Services (Microservices, nd) where application processes are kept as independent as possible from one another, resulting in minimal cascading failures during downtime, and easy replication and recovery of services. As such, data feeds are often given their own separate Application Programming Interface (API) (Application Programming Interface, nd) so as to separate concerns more easily (*i.e. querying for data is separated from processing data*). The consequence of this design is a large increase in network traffic over the Internet to facilitate communication between these largely independent and often replicated application processes. As of 2018, the optimal message format that reduces network traffic between application processes is JavaScript Object Notation (JSON) (Bray, 2017).
#
# In this section, we focus on scraping data from web pages and resources, and also accessing web APIs. As data sources, web APIs have become the de-facto querying method for the majority of enterprises to both deliver services and consume data feeds.

# %% [markdown]
# ## Types of Websites

# %% [markdown]
# In this section we focus on extraction of data from an online data source.
#
# Data sources can vary widely with respect to *accessibility*.
# Internal data sources are more easily accessible, and typically are not subject to special copyright or intellectual property laws. Internal data sources tend to be personal, or data generated by an agent or organization individually. External data sources tend to be data shared by others collectively for profiling or aggregation purposes.
#
# Here are some examples of internal and external data:
#
# | **Internal**               | **External**                                  |
# | ---: | --- |
# | Transactional              | Financial markets                             |
# | Systems health             | Events and news feeds                         |
# | Financial                  | Social media (Twitter, LinkedIn, Facebook)    |
# | Concepts / classifications | Location-based (cellphones, tracking devices) |
# | Documents or other text    | Social and economic databases                 |
# | Email                      | Open Data                                     |
# | Devices                    | 3rd-party data vendors                        |

# %% [markdown]
# However, the resource types used for holding data are generally the same for both external and internal data. As such, we will focus on external data sources &mdash; the majority of which are made up of web resources. There are three  variants of resources:
#
# | Web Resource Variant | Description |
# | --- | --- |
# | Static pages | Static pages refers to web resources that stay the same after being initially loaded. *(i.e. html files or any file resource such as csv, excel, pdf, etc.)* |
# | Dynamic pages | These refer to pages with server-side or client-side code actively making changes after the initial page resources have been loaded. *(i.e. pages changed by dynamic javascript, or web application pages running server-side code.)* |
# | APIs | These refer to interfaces for accessing data housed in applications. In recent years, these have been standardized to use JavaScript Object Notation (JSON). |

# %%
# %conda install -c conda-forge bs4
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# Note: you may need to restart the kernel to use updated packages.
# Building graph of deps:   0%|          | 0/219 [00:00<?, ?it/s]
# Examining @/win-64::__archspec==1=x86_64:   0%|          | 0/219 [00:00<?, ?it/s]
# Examining nbclassic:   0%|          | 1/219 [00:00<00:00, 965.54it/s]
# Examining filelock:   1%|          | 2/219 [00:01<03:18,  1.09it/s]
# Examining filelock:   1%|1         | 3/219 [00:01<02:12,  1.64it/s]
# Examining transformers=4.3:   1%|1         | 3/219 [00:02<02:12,  1.64it/s]
# Examining transformers=4.3:   2%|1         | 4/219 [00:02<02:07,  1.69it/s]
# Examining pandas=1.2:   2%|1         | 4/219 [00:02<02:07,  1.69it/s]
# Examining pandas=1.2:   2%|2         | 5/219 [00:02<02:04,  1.72it/s]
# Examining traitlets:   2%|2         | 5/219 [00:04<02:04,  1.72it/s]
# Examining traitlets:   3%|2         | 6/219 [00:04<02:46,  1.28it/s]
# Examining prometheus_client:   3%|2         | 6/219 [00:04<02:46,  1.28it/s]
# Examining prometheus_client:   3%|3         | 7/219 [00:04<02:36,  1.36it/s]
# Examining requests=2.25:   3%|3         | 7/219 [00:06<02:36,  1.36it/s]
# Examining requests=2.25:   4%|3         | 8/219 [00:06<04:08,  1.18s/it]
# Examining scikit-learn=0.24:   4%|3         | 8/219 [00:07<04:08,  1.18s/it]
# Examining scikit-learn=0.24:   4%|4         | 9/219 [00:07<03:06,  1.13it/s]
# Examining packaging:   4%|4         | 9/219 [00:08<03:06,  1.13it/s]
# Examining packaging:   5%|4         | 10/219 [00:08<03:51,  1.11s/it]
# Examining jupyter_server:   5%|4         | 10/219 [00:09<03:51,  1.11s/it]
# Examining jupyter_server:   5%|5         | 11/219 [00:09<03:46,  1.09s/it]
# Examining icu:   5%|5         | 11/219 [00:28<03:46,  1.09s/it]
# Examining icu:   5%|5         | 12/219 [00:28<22:21,  6.48s/it]
# Examining pthread-stubs:   5%|5         | 12/219 [00:28<22:21,  6.48s/it]
# Examining setuptools:   6%|5         | 13/219 [00:28<22:14,  6.48s/it]
# Examining jupyterlab_pygments:   6%|6         | 14/219 [00:37<22:08,  6.48s/it]
# Examining jupyterlab_pygments:   7%|6         | 15/219 [00:37<15:00,  4.41s/it]
# Examining decorator:   7%|6         | 15/219 [00:37<15:00,  4.41s/it]
# Examining decorator:   7%|7         | 16/219 [00:37<11:55,  3.52s/it]
# Examining wcwidth:   7%|7         | 16/219 [00:38<11:55,  3.52s/it]
# Examining wcwidth:   8%|7         | 17/219 [00:38<09:45,  2.90s/it]
# Examining nbconvert:   8%|7         | 17/219 [00:38<09:45,  2.90s/it]
# Examining nbconvert:   8%|8         | 18/219 [00:38<07:46,  2.32s/it]
# Examining graphviz:   8%|8         | 18/219 [00:46<07:46,  2.32s/it]
# Examining graphviz:   9%|8         | 19/219 [00:46<11:59,  3.60s/it]
# Examining ca-certificates:   9%|8         | 19/219 [00:46<11:59,  3.60s/it]
# Examining prompt-toolkit:   9%|9         | 20/219 [00:46<11:55,  3.60s/it]
# Examining m2w64-gmp:  10%|9         | 21/219 [00:46<11:52,  3.60s/it]
# Examining m2w64-gmp:  10%|#         | 22/219 [00:46<06:03,  1.85s/it]
# Examining xz:  10%|#         | 22/219 [00:46<06:03,  1.85s/it]
# Examining jupyter_console:  11%|#         | 23/219 [00:46<06:01,  1.85s/it]
# Examining sniffio:  11%|#         | 24/219 [00:54<05:59,  1.85s/it]
# Examining sniffio:  11%|#1        | 25/219 [00:54<06:41,  2.07s/it]
# Examining send2trash:  11%|#1        | 25/219 [00:54<06:41,  2.07s/it]
# Examining send2trash:  12%|#1        | 26/219 [00:54<05:37,  1.75s/it]
# Examining anyio:  12%|#1        | 26/219 [00:54<05:37,  1.75s/it]
# Examining anyio:  12%|#2        | 27/219 [00:54<04:38,  1.45s/it]
# Examining regex:  12%|#2        | 27/219 [00:55<04:38,  1.45s/it]
# Examining regex:  13%|#2        | 28/219 [00:55<04:10,  1.31s/it]
# Examining jasper:  13%|#2        | 28/219 [00:57<04:10,  1.31s/it]
# Examining jasper:  13%|#3        | 29/219 [00:57<05:02,  1.59s/it]
# Examining win_inet_pton:  13%|#3        | 29/219 [00:57<05:02,  1.59s/it]
# Examining fonts-conda-ecosystem:  14%|#3        | 30/219 [00:58<05:01,  1.59s/it]
# Examining fonts-conda-ecosystem:  14%|#4        | 31/219 [00:58<03:07,  1.00it/s]
# Examining backcall:  14%|#4        | 31/219 [00:58<03:07,  1.00it/s]
# Examining tokenizers:  15%|#4        | 32/219 [00:58<03:06,  1.00it/s]
# Examining tokenizers:  15%|#5        | 33/219 [00:58<02:03,  1.51it/s]
# Examining pyzmq:  15%|#5        | 33/219 [00:58<02:03,  1.51it/s]
# Examining pyzmq:  16%|#5        | 34/219 [00:58<01:41,  1.82it/s]
# Examining nbclient:  16%|#5        | 34/219 [00:59<01:41,  1.82it/s]
# Examining nbclient:  16%|#5        | 35/219 [00:59<02:13,  1.38it/s]
# Examining lcms2:  16%|#5        | 35/219 [01:00<02:13,  1.38it/s]
# Examining lcms2:  16%|#6        | 36/219 [01:00<02:06,  1.45it/s]
# Examining lerc:  16%|#6        | 36/219 [01:00<02:06,  1.45it/s]
# Examining harfbuzz:  17%|#6        | 37/219 [01:00<02:05,  1.45it/s]
# Examining libsodium:  17%|#7        | 38/219 [01:00<02:04,  1.45it/s]
# Examining libsodium:  18%|#7        | 39/219 [01:00<01:07,  2.67it/s]
# Examining pyqt-impl:  18%|#7        | 39/219 [01:00<01:07,  2.67it/s]
# Examining pyqtwebengine:  18%|#8        | 40/219 [01:00<01:07,  2.67it/s]
# Examining bs4:  19%|#8        | 41/219 [01:00<01:06,  2.67it/s]
# Examining bs4:  19%|#9        | 42/219 [01:00<00:42,  4.20it/s]
# Examining dataclasses:  19%|#9        | 42/219 [01:00<00:42,  4.20it/s]
# Examining xorg-libxpm:  20%|#9        | 43/219 [01:00<00:41,  4.20it/s]
# Examining xorg-libxpm:  20%|##        | 44/219 [01:00<00:34,  5.14it/s]
# Examining zlib:  20%|##        | 44/219 [01:00<00:34,  5.14it/s]
# Examining expat:  21%|##        | 45/219 [01:00<00:33,  5.14it/s]
# Examining matplotlib-base:  21%|##1       | 46/219 [01:00<00:33,  5.14it/s]
# Examining matplotlib-base:  21%|##1       | 47/219 [01:20<00:33,  5.14it/s]
# Examining vs2015_runtime:  21%|##1       | 47/219 [01:22<00:33,  5.14it/s]
# Examining vs2015_runtime:  22%|##1       | 48/219 [01:22<07:13,  2.54s/it]
# Examining jupyterlab_widgets:  22%|##1       | 48/219 [01:22<07:13,  2.54s/it]
# Examining jpeg:  22%|##2       | 49/219 [01:22<07:11,  2.54s/it]
# Examining jpeg:  23%|##2       | 50/219 [01:22<05:27,  1.94s/it]
# Examining terminado:  23%|##2       | 50/219 [01:22<05:27,  1.94s/it]
# Examining pysocks:  23%|##3       | 51/219 [01:25<05:25,  1.94s/it]
# Examining pysocks:  24%|##3       | 52/219 [01:25<05:02,  1.81s/it]
# Examining libcblas:  24%|##3       | 52/219 [01:25<05:02,  1.81s/it]
# Examining libcblas:  24%|##4       | 53/219 [01:25<04:25,  1.60s/it]
# Examining py-opencv:  24%|##4       | 53/219 [01:25<04:25,  1.60s/it]
# Examining pycparser:  25%|##4       | 54/219 [01:33<04:23,  1.60s/it]
# Examining pycparser:  25%|##5       | 55/219 [01:33<06:06,  2.23s/it]
# Examining notebook:  25%|##5       | 55/219 [01:33<06:06,  2.23s/it]
# Examining notebook:  26%|##5       | 56/219 [01:33<05:12,  1.91s/it]
# Examining xorg-kbproto:  26%|##5       | 56/219 [02:26<05:12,  1.91s/it]
# Examining xorg-kbproto:  26%|##6       | 57/219 [02:26<33:26, 12.38s/it]
# Examining cryptography:  26%|##6       | 57/219 [02:26<33:26, 12.38s/it]
# Examining xorg-libxt:  26%|##6       | 58/219 [02:33<33:13, 12.38s/it]
# Examining xorg-libxt:  27%|##6       | 59/219 [02:33<24:20,  9.13s/it]
# Examining idna:  27%|##6       | 59/219 [02:33<24:20,  9.13s/it]
# Examining winpty:  27%|##7       | 60/219 [02:34<24:11,  9.13s/it]
# Examining winpty:  28%|##7       | 61/219 [02:34<16:00,  6.08s/it]
# Examining gettext:  28%|##7       | 61/219 [02:34<16:00,  6.08s/it]
# Examining kiwisolver:  28%|##8       | 62/219 [02:34<15:54,  6.08s/it]
# Examining libdeflate:  29%|##8       | 63/219 [02:34<15:48,  6.08s/it]
# Examining libdeflate:  29%|##9       | 64/219 [02:34<09:12,  3.57s/it]
# Examining cycler:  29%|##9       | 64/219 [02:34<09:12,  3.57s/it]
# Examining pcre:  30%|##9       | 65/219 [02:35<09:09,  3.57s/it]
# Examining pcre:  30%|###       | 66/219 [02:35<06:32,  2.56s/it]
# Examining bleach:  30%|###       | 66/219 [02:35<06:32,  2.56s/it]
# Examining qt:  31%|###       | 67/219 [02:40<06:29,  2.56s/it]
# Examining qt:  31%|###1      | 68/219 [02:40<06:26,  2.56s/it]
# Examining backports:  31%|###1      | 68/219 [02:40<06:26,  2.56s/it]
# Examining backports:  32%|###1      | 69/219 [02:40<05:23,  2.15s/it]
# Examining ffmpeg:  32%|###1      | 69/219 [02:40<05:23,  2.15s/it]
# Examining ffmpeg:  32%|###1      | 70/219 [02:40<04:22,  1.76s/it]
# Examining pyopengl=3.1:  32%|###1      | 70/219 [02:40<04:22,  1.76s/it]
# Examining olefile:  32%|###2      | 71/219 [02:40<04:20,  1.76s/it]
# Examining olefile:  33%|###2      | 72/219 [02:40<02:50,  1.16s/it]
# Examining ipython=7.20:  33%|###2      | 72/219 [02:40<02:50,  1.16s/it]
# Examining ipython=7.20:  33%|###3      | 73/219 [02:40<02:22,  1.02it/s]
# Examining xorg-libx11:  33%|###3      | 73/219 [02:41<02:22,  1.02it/s]
# Examining xorg-libx11:  34%|###3      | 74/219 [02:41<02:22,  1.02it/s]
# Examining libprotobuf:  34%|###3      | 74/219 [02:42<02:22,  1.02it/s]
# Examining zipp:  34%|###4      | 75/219 [02:42<02:21,  1.02it/s]
# Examining zipp:  35%|###4      | 76/219 [02:42<01:30,  1.59it/s]
# Examining pyglet=1.5:  35%|###4      | 76/219 [02:43<01:30,  1.59it/s]
# Examining pyglet=1.5:  35%|###5      | 77/219 [02:43<01:44,  1.36it/s]
# Examining xorg-libxau:  35%|###5      | 77/219 [02:44<01:44,  1.36it/s]
# Examining xorg-libxau:  36%|###5      | 78/219 [02:44<01:48,  1.30it/s]
# Examining gts:  36%|###5      | 78/219 [02:44<01:48,  1.30it/s]
# Examining jupyterlab_server:  36%|###6      | 79/219 [02:44<01:47,  1.30it/s]
# Examining m2w64-gcc-libgfortran:  37%|###6      | 80/219 [02:52<01:46,  1.30it/s]
# Examining m2w64-gcc-libgfortran:  37%|###6      | 81/219 [02:52<04:11,  1.82s/it]
# Examining tbb:  37%|###6      | 81/219 [02:52<04:11,  1.82s/it]
# Examining webencodings:  37%|###7      | 82/219 [02:52<04:09,  1.82s/it]
# Examining libclang:  38%|###7      | 83/219 [02:52<04:07,  1.82s/it]
# Examining libclang:  38%|###8      | 84/219 [02:52<02:25,  1.08s/it]
# Examining jupyter_core:  38%|###8      | 84/219 [02:52<02:25,  1.08s/it]
# Examining python=3.7:  39%|###8      | 85/219 [02:54<02:24,  1.08s/it]
# Examining python=3.7:  39%|###9      | 86/219 [02:54<02:15,  1.02s/it]
# Examining libiconv:  39%|###9      | 86/219 [02:56<02:15,  1.02s/it]
# Examining libiconv:  40%|###9      | 87/219 [02:56<02:23,  1.09s/it]
# Examining nbformat:  40%|###9      | 87/219 [02:56<02:23,  1.09s/it]
# Examining smmap:  40%|####      | 88/219 [02:57<02:22,  1.09s/it]
# Examining smmap:  41%|####      | 89/219 [02:57<02:13,  1.02s/it]
# Examining ucrt:  41%|####      | 89/219 [02:58<02:13,  1.02s/it]
# Examining ucrt:  41%|####1     | 90/219 [02:58<01:57,  1.10it/s]
# Examining freeglut:  41%|####1     | 90/219 [02:58<01:57,  1.10it/s]
# Examining tornado:  42%|####1     | 91/219 [02:58<01:56,  1.10it/s]
# Examining cffi:  42%|####2     | 92/219 [02:59<01:55,  1.10it/s]
# Examining cffi:  42%|####2     | 93/219 [02:59<01:24,  1.50it/s]
# Examining openssl:  42%|####2     | 93/219 [03:00<01:24,  1.50it/s]
# Examining openssl:  43%|####2     | 94/219 [03:00<01:36,  1.30it/s]
# Examining font-ttf-inconsolata:  43%|####2     | 94/219 [03:00<01:36,  1.30it/s]
# Examining pickleshare:  43%|####3     | 95/219 [03:00<01:35,  1.30it/s]
# Examining _py-xgboost-mutex:  44%|####3     | 96/219 [03:00<01:34,  1.30it/s]
# Examining _py-xgboost-mutex:  44%|####4     | 97/219 [03:00<00:59,  2.04it/s]
# Examining matplotlib=3.3:  44%|####4     | 97/219 [03:00<00:59,  2.04it/s]
# Examining libgd:  45%|####4     | 98/219 [03:01<00:59,  2.04it/s]
# Examining libgd:  45%|####5     | 99/219 [03:01<00:48,  2.46it/s]
# Examining jupyter=1.0:  45%|####5     | 99/219 [03:01<00:48,  2.46it/s]
# Examining zeromq:  46%|####5     | 100/219 [03:14<00:48,  2.46it/s]
# Examining zeromq:  46%|####6     | 101/219 [03:14<04:16,  2.18s/it]
# Examining wheel:  46%|####6     | 101/219 [03:14<04:16,  2.18s/it]
# Examining nbdime=2.1:  47%|####6     | 102/219 [03:22<04:14,  2.18s/it]
# Examining nbdime=2.1:  47%|####7     | 103/219 [03:22<05:13,  2.70s/it]
# Examining parso:  47%|####7     | 103/219 [03:22<05:13,  2.70s/it]
# Examining parso:  47%|####7     | 104/219 [03:22<04:19,  2.26s/it]
# Examining defusedxml:  47%|####7     | 104/219 [03:23<04:19,  2.26s/it]
# Examining defusedxml:  48%|####7     | 105/219 [03:23<03:54,  2.06s/it]
# Examining qtconsole:  48%|####7     | 105/219 [03:23<03:54,  2.06s/it]
# Examining qtconsole:  48%|####8     | 106/219 [03:23<03:07,  1.66s/it]
# Examining pixman:  48%|####8     | 106/219 [03:34<03:07,  1.66s/it]
# Examining pixman:  49%|####8     | 107/219 [03:34<07:00,  3.75s/it]
# Examining xorg-xextproto:  49%|####8     | 107/219 [03:34<07:00,  3.75s/it]
# Examining async_generator:  49%|####9     | 108/219 [03:34<06:56,  3.75s/it]
# Examining python_abi:  50%|####9     | 109/219 [03:34<06:53,  3.75s/it]
# Examining python_abi:  50%|#####     | 110/219 [03:34<03:24,  1.88s/it]
# Examining libxgboost:  50%|#####     | 110/219 [03:34<03:24,  1.88s/it]
# Examining pyopenssl:  51%|#####     | 111/219 [03:34<03:22,  1.88s/it]
# Examining xorg-libxdmcp:  51%|#####1    | 112/219 [03:37<03:20,  1.88s/it]
# Examining xorg-libxdmcp:  52%|#####1    | 113/219 [03:37<02:41,  1.53s/it]
# Examining xorg-libice:  52%|#####1    | 113/219 [03:37<02:41,  1.53s/it]
# Examining font-ttf-source-code-pro:  52%|#####2    | 114/219 [03:37<02:40,  1.53s/it]
# Examining gitpython:  53%|#####2    | 115/219 [03:37<02:38,  1.53s/it]
# Examining freetype:  53%|#####2    | 116/219 [03:39<02:37,  1.53s/it]
# Examining freetype:  53%|#####3    | 117/219 [03:39<01:44,  1.02s/it]
# Examining qtpy:  53%|#####3    | 117/219 [03:39<01:44,  1.02s/it]
# Examining qtpy:  54%|#####3    | 118/219 [03:39<01:32,  1.10it/s]
# Examining threadpoolctl:  54%|#####3    | 118/219 [03:40<01:32,  1.10it/s]
# Examining threadpoolctl:  54%|#####4    | 119/219 [03:40<01:31,  1.10it/s]
# Examining lz4-c:  54%|#####4    | 119/219 [03:40<01:31,  1.10it/s]
# Examining lz4-c:  55%|#####4    | 120/219 [03:40<01:16,  1.29it/s]
# Examining future:  55%|#####4    | 120/219 [03:40<01:16,  1.29it/s]
# Examining font-ttf-dejavu-sans-mono:  55%|#####5    | 121/219 [03:40<01:16,  1.29it/s]
# Examining font-ttf-dejavu-sans-mono:  56%|#####5    | 122/219 [03:40<00:55,  1.74it/s]
# Examining certifi:  56%|#####5    | 122/219 [03:40<00:55,  1.74it/s]
# Examining backports.functools_lru_cache:  56%|#####6    | 123/219 [03:41<00:55,  1.74it/s]
# Examining backports.functools_lru_cache:  57%|#####6    | 124/219 [03:41<00:54,  1.73it/s]
# Examining websocket-client:  57%|#####6    | 124/219 [03:43<00:54,  1.73it/s]
# Examining websocket-client:  57%|#####7    | 125/219 [03:43<01:15,  1.25it/s]
# Examining libxcb:  57%|#####7    | 125/219 [03:44<01:15,  1.25it/s]
# Examining libxcb:  58%|#####7    | 126/219 [03:44<01:14,  1.25it/s]
# Examining libwebp-base:  58%|#####7    | 126/219 [03:44<01:14,  1.25it/s]
# Examining widgetsnbextension=3.5:  58%|#####7    | 127/219 [03:44<01:13,  1.25it/s]
# Examining ftfy=5.8:  58%|#####8    | 128/219 [03:48<01:12,  1.25it/s]
# Examining ftfy=5.8:  59%|#####8    | 129/219 [03:48<01:32,  1.02s/it]
# Examining box2d-py=2.3:  59%|#####8    | 129/219 [03:48<01:32,  1.02s/it]
# Examining box2d-py=2.3:  59%|#####9    | 130/219 [03:48<01:17,  1.15it/s]
# Examining font-ttf-ubuntu:  59%|#####9    | 130/219 [03:48<01:17,  1.15it/s]
# Examining font-ttf-ubuntu:  60%|#####9    | 131/219 [03:48<01:02,  1.41it/s]
# Examining intel-openmp:  60%|#####9    | 131/219 [03:48<01:02,  1.41it/s]
# Examining requests-unixsocket:  60%|######    | 132/219 [03:48<01:01,  1.41it/s]
# Examining pango:  61%|######    | 133/219 [03:48<01:01,  1.41it/s]
# Examining pango:  61%|######1   | 134/219 [03:48<00:34,  2.44it/s]
# Examining jinja2:  61%|######1   | 134/219 [03:48<00:34,  2.44it/s]
# Examining jinja2:  62%|######1   | 135/219 [03:48<00:29,  2.83it/s]
# Examining ipython_genutils:  62%|######1   | 135/219 [03:52<00:29,  2.83it/s]
# Examining ipython_genutils:  62%|######2   | 136/219 [03:52<01:22,  1.00it/s]
# Examining xorg-xproto:  62%|######2   | 136/219 [03:52<01:22,  1.00it/s]
# Examining xorg-xproto:  63%|######2   | 137/219 [03:52<01:05,  1.25it/s]
# Examining numpy=1.19:  63%|######2   | 137/219 [03:52<01:05,  1.25it/s]
# Examining jbig:  63%|######3   | 138/219 [03:53<01:04,  1.25it/s]
# Examining jbig:  63%|######3   | 139/219 [03:53<00:51,  1.55it/s]
# Examining pytz:  63%|######3   | 139/219 [03:53<00:51,  1.55it/s]
# Examining m2w64-libwinpthread-git:  64%|######3   | 140/219 [03:54<00:51,  1.55it/s]
# Examining m2w64-libwinpthread-git:  64%|######4   | 141/219 [03:54<00:45,  1.72it/s]
# Examining cloudpickle:  64%|######4   | 141/219 [03:54<00:45,  1.72it/s]
# Examining pandoc:  65%|######4   | 142/219 [03:55<00:44,  1.72it/s]
# Examining pandoc:  65%|######5   | 143/219 [03:55<00:47,  1.59it/s]
# Examining python-dateutil:  65%|######5   | 143/219 [03:55<00:47,  1.59it/s]
# Examining pip:  66%|######5   | 144/219 [03:56<00:47,  1.59it/s]
# Examining pip:  66%|######6   | 145/219 [03:56<00:38,  1.91it/s]
# Examining libopencv:  66%|######6   | 145/219 [04:12<00:38,  1.91it/s]
# Examining libopencv:  67%|######6   | 146/219 [04:12<04:14,  3.49s/it]
# Examining nest-asyncio:  67%|######6   | 146/219 [04:14<04:14,  3.49s/it]
# Examining nest-asyncio:  67%|######7   | 147/219 [04:14<03:48,  3.17s/it]
# Examining py-xgboost=0.90:  67%|######7   | 147/219 [04:14<03:48,  3.17s/it]
# Examining py-xgboost=0.90:  68%|######7   | 148/219 [04:14<03:00,  2.54s/it]
# Examining babel:  68%|######7   | 148/219 [04:16<03:00,  2.54s/it]
# Examining babel:  68%|######8   | 149/219 [04:16<02:34,  2.21s/it]
# Examining libpng:  68%|######8   | 149/219 [04:16<02:34,  2.21s/it]
# Examining libpng:  68%|######8   | 150/219 [04:16<02:02,  1.78s/it]
# Examining fribidi:  68%|######8   | 150/219 [04:16<02:02,  1.78s/it]
# Examining atari_py=0.2:  69%|######8   | 151/219 [04:16<02:01,  1.78s/it]
# Examining libtiff:  69%|######9   | 152/219 [04:18<01:59,  1.78s/it]
# Examining libtiff:  70%|######9   | 153/219 [04:18<01:10,  1.07s/it]
# Examining opencv=4.5:  70%|######9   | 153/219 [04:18<01:10,  1.07s/it]
# Examining opencv=4.5:  70%|#######   | 154/219 [04:18<00:57,  1.12it/s]
# Examining tqdm=4.56:  70%|#######   | 154/219 [04:18<00:57,  1.12it/s]
# Examining pillow=8.1:  71%|#######   | 155/219 [04:18<00:56,  1.12it/s]
# Examining pillow=8.1:  71%|#######1  | 156/219 [04:18<00:37,  1.70it/s]
# Examining mkl:  71%|#######1  | 156/219 [04:18<00:37,  1.70it/s]
# Examining mkl:  72%|#######1  | 157/219 [04:18<00:34,  1.78it/s]
# Examining cairo:  72%|#######1  | 157/219 [04:18<00:34,  1.78it/s]
# Examining prompt_toolkit:  72%|#######2  | 158/219 [04:19<00:34,  1.78it/s]
# Examining prompt_toolkit:  73%|#######2  | 159/219 [04:19<00:24,  2.46it/s]
# Examining importlib-metadata:  73%|#######2  | 159/219 [04:20<00:24,  2.46it/s]
# Examining importlib-metadata:  73%|#######3  | 160/219 [04:20<00:38,  1.54it/s]
# Examining numexpr=2.7:  73%|#######3  | 160/219 [04:22<00:38,  1.54it/s]
# Examining numexpr=2.7:  74%|#######3  | 161/219 [04:22<00:49,  1.18it/s]
# Examining json5:  74%|#######3  | 161/219 [04:26<00:49,  1.18it/s]
# Examining json5:  74%|#######3  | 162/219 [04:26<01:42,  1.80s/it]
# Examining liblapacke:  74%|#######3  | 162/219 [04:27<01:42,  1.80s/it]
# Examining liblapacke:  74%|#######4  | 163/219 [04:27<01:22,  1.48s/it]
# Examining fontconfig:  74%|#######4  | 163/219 [04:27<01:22,  1.48s/it]
# Examining fonts-conda-forge:  75%|#######4  | 164/219 [04:27<01:21,  1.48s/it]
# Examining fonts-conda-forge:  75%|#######5  | 165/219 [04:27<00:47,  1.15it/s]
# Examining attrs:  75%|#######5  | 165/219 [04:27<00:47,  1.15it/s]
# Examining jupyterlab:  76%|#######5  | 166/219 [04:30<00:46,  1.15it/s]
# Examining jupyterlab:  76%|#######6  | 167/219 [04:30<00:54,  1.04s/it]
# Examining openjpeg:  76%|#######6  | 167/219 [05:38<00:54,  1.04s/it]
# Examining openjpeg:  77%|#######6  | 168/219 [05:38<12:59, 15.29s/it]
# Examining pyqtchart:  77%|#######6  | 168/219 [05:38<12:59, 15.29s/it]
# Examining pyqtchart:  77%|#######7  | 169/219 [05:38<09:50, 11.81s/it]
# Examining pygments:  77%|#######7  | 169/219 [05:38<09:50, 11.81s/it]
# Examining gym=0.18:  78%|#######7  | 170/219 [05:42<09:38, 11.81s/it]
# Examining gym=0.18:  78%|#######8  | 171/219 [05:42<06:15,  7.82s/it]
# Examining nltk=3.4:  78%|#######8  | 171/219 [05:42<06:15,  7.82s/it]
# Examining nltk=3.4:  79%|#######8  | 172/219 [05:42<04:54,  6.26s/it]
# Examining pywin32:  79%|#######8  | 172/219 [05:44<04:54,  6.26s/it]
# Examining pywin32:  79%|#######8  | 173/219 [05:44<03:53,  5.08s/it]
# Examining ipykernel:  79%|#######8  | 173/219 [05:44<03:53,  5.08s/it]
# Examining ipykernel:  79%|#######9  | 174/219 [05:44<02:55,  3.89s/it]
# Examining mistune:  79%|#######9  | 174/219 [06:12<02:55,  3.89s/it]
# Examining mistune:  80%|#######9  | 175/219 [06:12<07:31, 10.25s/it]
# Examining sacremoses:  80%|#######9  | 175/219 [06:12<07:31, 10.25s/it]
# Examining sacremoses:  80%|########  | 176/219 [06:12<05:23,  7.53s/it]
# Examining click:  80%|########  | 176/219 [06:13<05:23,  7.53s/it]
# Examining click:  81%|########  | 177/219 [06:13<03:53,  5.55s/it]
# Examining scipy=1.6:  81%|########  | 177/219 [06:14<03:53,  5.55s/it]
# Examining scipy=1.6:  81%|########1 | 178/219 [06:14<02:50,  4.17s/it]
# Examining libglib:  81%|########1 | 178/219 [06:14<02:50,  4.17s/it]
# Examining libglib:  82%|########1 | 179/219 [06:14<02:07,  3.18s/it]
# Examining libxml2:  82%|########1 | 179/219 [06:14<02:07,  3.18s/it]
# Examining pandocfilters:  82%|########2 | 180/219 [06:15<02:04,  3.18s/it]
# Examining pandocfilters:  83%|########2 | 181/219 [06:15<01:08,  1.79s/it]
# Examining libffi:  83%|########2 | 181/219 [06:15<01:08,  1.79s/it]
# Examining libffi:  83%|########3 | 182/219 [06:15<00:51,  1.39s/it]
# Examining m2w64-gcc-libs:  83%|########3 | 182/219 [06:15<00:51,  1.39s/it]
# Examining xorg-libsm:  84%|########3 | 183/219 [06:15<00:50,  1.39s/it]
# Examining pyqt5-sip:  84%|########4 | 184/219 [06:15<00:48,  1.39s/it]
# Examining markupsafe:  84%|########4 | 185/219 [06:15<00:47,  1.39s/it]
# Examining brotlipy:  85%|########4 | 186/219 [06:15<00:45,  1.39s/it]
# Examining brotlipy:  85%|########5 | 187/219 [06:15<00:18,  1.74it/s]
# Examining jsonschema:  85%|########5 | 187/219 [06:16<00:18,  1.74it/s]
# Examining jsonschema:  86%|########5 | 188/219 [06:16<00:19,  1.62it/s]
# Examining tk:  86%|########5 | 188/219 [06:22<00:19,  1.62it/s]
# Examining tk:  86%|########6 | 189/219 [06:22<00:46,  1.54s/it]
# Examining zstd:  86%|########6 | 189/219 [06:22<00:46,  1.54s/it]
# Examining jedi:  87%|########6 | 190/219 [06:22<00:44,  1.54s/it]
# Examining jedi:  87%|########7 | 191/219 [06:22<00:29,  1.04s/it]
# Examining @/win-64::__win==0=0:  87%|########7 | 191/219 [06:23<00:29,  1.04s/it]
# Examining @/win-64::__win==0=0:  88%|########7 | 192/219 [06:23<00:29,  1.07s/it]
# Examining jupyter_client:  88%|########7 | 192/219 [06:23<00:29,  1.07s/it]
# Examining libwebp:  88%|########8 | 193/219 [06:31<00:27,  1.07s/it]
# Examining libwebp:  89%|########8 | 194/219 [06:31<00:50,  2.00s/it]
# Examining sqlite:  89%|########8 | 194/219 [06:31<00:50,  2.00s/it]
# Examining vc:  89%|########9 | 195/219 [06:31<00:48,  2.00s/it]
# Examining xorg-libxext:  89%|########9 | 196/219 [06:31<00:46,  2.00s/it]
# Examining chardet:  90%|########9 | 197/219 [06:31<00:44,  2.00s/it]
# Examining chardet:  90%|######### | 198/219 [06:31<00:21,  1.00s/it]
# Examining gitdb:  90%|######### | 198/219 [06:31<00:21,  1.00s/it]
# Examining ipywidgets=7.6:  91%|######### | 199/219 [06:31<00:20,  1.00s/it]
# Examining ipywidgets=7.6:  91%|#########1| 200/219 [06:31<00:15,  1.19it/s]
# Examining joblib=0.14:  91%|#########1| 200/219 [06:33<00:15,  1.19it/s]
# Examining joblib=0.14:  92%|#########1| 201/219 [06:33<00:18,  1.01s/it]
# Examining python-graphviz:  92%|#########1| 201/219 [06:34<00:18,  1.01s/it]
# Examining python-graphviz:  92%|#########2| 202/219 [06:34<00:15,  1.10it/s]
# Examining pyrsistent:  92%|#########2| 202/219 [06:35<00:15,  1.10it/s]
# Examining pyrsistent:  93%|#########2| 203/219 [06:35<00:15,  1.02it/s]
# Examining pyqt:  93%|#########2| 203/219 [06:36<00:15,  1.02it/s]
# Examining pyqt:  93%|#########3| 204/219 [06:36<00:15,  1.01s/it]
# Examining entrypoints:  93%|#########3| 204/219 [06:37<00:15,  1.01s/it]
# Examining entrypoints:  94%|#########3| 205/219 [06:37<00:12,  1.09it/s]
# Examining pyparsing:  94%|#########3| 205/219 [06:37<00:12,  1.09it/s]
# Examining pyparsing:  94%|#########4| 206/219 [06:37<00:09,  1.34it/s]
# Examining urllib3:  94%|#########4| 206/219 [06:38<00:09,  1.34it/s]
# Examining urllib3:  95%|#########4| 207/219 [06:38<00:09,  1.20it/s]
# Examining testpath:  95%|#########4| 207/219 [06:50<00:09,  1.20it/s]
# Examining testpath:  95%|#########4| 208/219 [06:50<00:43,  3.93s/it]
# Examining graphite2:  95%|#########4| 208/219 [06:50<00:43,  3.93s/it]
# Examining graphite2:  95%|#########5| 209/219 [06:50<00:29,  2.92s/it]
# Examining colorama:  95%|#########5| 209/219 [06:50<00:29,  2.92s/it]
# Examining liblapack:  96%|#########5| 210/219 [06:51<00:26,  2.92s/it]
# Examining liblapack:  96%|#########6| 211/219 [06:51<00:13,  1.71s/it]
# Examining msys2-conda-epoch:  96%|#########6| 211/219 [06:51<00:13,  1.71s/it]
# Examining argon2-cffi:  97%|#########6| 212/219 [06:51<00:11,  1.71s/it]
# Examining getopt-win32:  97%|#########7| 213/219 [06:53<00:10,  1.71s/it]
# Examining getopt-win32:  98%|#########7| 214/219 [06:53<00:05,  1.19s/it]
# Examining m2w64-gcc-libs-core:  98%|#########7| 214/219 [06:53<00:05,  1.19s/it]
# Examining six:  98%|#########8| 215/219 [06:53<00:04,  1.19s/it]
# Examining libblas:  99%|#########8| 216/219 [06:53<00:03,  1.19s/it]
# Examining libblas:  99%|#########9| 217/219 [06:53<00:01,  1.29it/s]
# Examining typing_extensions:  99%|#########9| 217/219 [06:53<00:01,  1.29it/s]
# Examining pywinpty: 100%|#########9| 218/219 [06:54<00:00,  1.29it/s]
# Examining pywinpty: 100%|##########| 219/219 [06:54<00:00,  1.55it/s]
#
#
# Determining conflicts:   0%|          | 0/219 [00:00<?, ?it/s]
# Examining conflict for jupyterlab nbclassic:   0%|          | 0/219 [00:00<?, ?it/s]
# Examining conflict for jupyterlab nbclassic notebook nltk ipykernel jupyter_server nbconvert widgetsnbextension jupyter_client jupyter_console jupyterlab_server ipywidgets nbclient tornado matplotlib jupyter nbdime matplotlib-base qtconsole terminado:   0%|          | 1/219 [00:00<01:03,  3.42it/s]
# Examining conflict for jupyterlab nbclassic notebook nltk ipykernel jupyter_server nbconvert widgetsnbextension jupyter_client jupyter_console jupyterlab_server ipywidgets nbclient tornado matplotlib jupyter nbdime matplotlib-base qtconsole terminado:   1%|          | 2/219 [00:00<00:31,  6.84it/s]
# Examining conflict for nbclassic filelock pandas transformers traitlets requests prometheus_client scikit-learn packaging jupyter_server setuptools wcwidth jupyterlab_pygments decorator nbconvert prompt-toolkit jupyter_console sniffio send2trash anyio regex win_inet_pton backcall tokenizers pyzmq nbclient pyqt-impl harfbuzz pyqtwebengine bs4 dataclasses matplotlib-base jupyterlab_widgets terminado pysocks py-opencv pycparser notebook cryptography idna kiwisolver cycler bleach backports pyopengl olefile ipython zipp pyglet gts jupyterlab_server webencodings nbformat jupyter_core python smmap tornado cffi pickleshare matplotlib jupyter wheel nbdime parso defusedxml qtconsole async_generator python_abi pyopenssl gitpython qtpy threadpoolctl future websocket-client certifi backports.functools_lru_cache widgetsnbextension ftfy box2d-py requests-unixsocket pango jinja2 ipython_genutils numpy pytz cloudpickle python-dateutil pip libopencv nest-asyncio py-xgboost babel atari_py opencv tqdm pillow prompt_toolkit cairo importlib-metadata numexpr json5 pyqtchart attrs jupyterlab pygments gym nltk pywin32 ipykernel mistune sacremoses click scipy pandocfilters pyqt5-sip markupsafe brotlipy jsonschema zstd jedi jupyter_client chardet gitdb ipywidgets joblib python-graphviz pyrsistent pyqt entrypoints pyparsing urllib3 testpath colorama argon2-cffi six typing_extensions pywinpty:   1%|          | 2/219 [00:02<00:31,  6.84it/s]
# Examining conflict for nbclassic filelock pandas transformers traitlets requests prometheus_client scikit-learn packaging jupyter_server setuptools wcwidth jupyterlab_pygments decorator nbconvert prompt-toolkit jupyter_console sniffio send2trash anyio regex win_inet_pton backcall tokenizers pyzmq nbclient pyqt-impl harfbuzz pyqtwebengine bs4 dataclasses matplotlib-base jupyterlab_widgets terminado pysocks py-opencv pycparser notebook cryptography idna kiwisolver cycler bleach backports pyopengl olefile ipython zipp pyglet gts jupyterlab_server webencodings nbformat jupyter_core python smmap tornado cffi pickleshare matplotlib jupyter wheel nbdime parso defusedxml qtconsole async_generator python_abi pyopenssl gitpython qtpy threadpoolctl future websocket-client certifi backports.functools_lru_cache widgetsnbextension ftfy box2d-py requests-unixsocket pango jinja2 ipython_genutils numpy pytz cloudpickle python-dateutil pip libopencv nest-asyncio py-xgboost babel atari_py opencv tqdm pillow prompt_toolkit cairo importlib-metadata numexpr json5 pyqtchart attrs jupyterlab pygments gym nltk pywin32 ipykernel mistune sacremoses click scipy pandocfilters pyqt5-sip markupsafe brotlipy jsonschema zstd jedi jupyter_client chardet gitdb ipywidgets joblib python-graphviz pyrsistent pyqt entrypoints pyparsing urllib3 testpath colorama argon2-cffi six typing_extensions pywinpty:   1%|1         | 3/219 [00:02<03:46,  1.05s/it]
# Examining conflict for jupyterlab_server jupyterlab nbclassic anyio jupyter_server:   1%|1         | 3/219 [00:15<03:46,  1.05s/it]
# Examining conflict for jupyterlab_server jupyterlab nbclassic anyio jupyter_server:   2%|1         | 4/219 [00:15<20:02,  5.59s/it]
# Examining conflict for nbclassic filelock pandas transformers traitlets requests prometheus_client scikit-learn packaging jupyter_server setuptools wcwidth jupyterlab_pygments decorator nbconvert prompt-toolkit jupyter_console sniffio send2trash anyio regex win_inet_pton backcall tokenizers pyzmq nbclient pyqt-impl pyqtwebengine dataclasses matplotlib-base jupyterlab_widgets terminado pysocks py-opencv pycparser notebook cryptography idna kiwisolver cycler bleach qt backports pyopengl olefile ipython zipp pyglet jupyterlab_server webencodings nbformat jupyter_core python smmap tornado cffi pickleshare matplotlib jupyter wheel nbdime parso defusedxml qtconsole async_generator python_abi pyopenssl gitpython qtpy threadpoolctl future websocket-client certifi backports.functools_lru_cache widgetsnbextension ftfy box2d-py requests-unixsocket jinja2 ipython_genutils numpy pytz cloudpickle python-dateutil pip libopencv nest-asyncio py-xgboost babel atari_py tqdm pillow prompt_toolkit importlib-metadata numexpr json5 pyqtchart attrs jupyterlab pygments gym nltk pywin32 ipykernel mistune sacremoses click scipy pandocfilters pyqt5-sip markupsafe brotlipy jsonschema jedi jupyter_client sqlite chardet gitdb ipywidgets joblib python-graphviz pyrsistent pyqt entrypoints pyparsing urllib3 testpath colorama argon2-cffi six typing_extensions pywinpty:   2%|1         | 4/219 [00:16<20:02,  5.59s/it]
# Examining conflict for nbclassic filelock pandas transformers traitlets requests prometheus_client scikit-learn packaging jupyter_server setuptools wcwidth jupyterlab_pygments decorator nbconvert prompt-toolkit jupyter_console sniffio send2trash anyio regex win_inet_pton backcall tokenizers pyzmq nbclient pyqt-impl pyqtwebengine dataclasses matplotlib-base jupyterlab_widgets terminado pysocks py-opencv pycparser notebook cryptography idna kiwisolver cycler bleach qt backports pyopengl olefile ipython zipp pyglet jupyterlab_server webencodings nbformat jupyter_core python smmap tornado cffi pickleshare matplotlib jupyter wheel nbdime parso defusedxml qtconsole async_generator python_abi pyopenssl gitpython qtpy threadpoolctl future websocket-client certifi backports.functools_lru_cache widgetsnbextension ftfy box2d-py requests-unixsocket jinja2 ipython_genutils numpy pytz cloudpickle python-dateutil pip libopencv nest-asyncio py-xgboost babel atari_py tqdm pillow prompt_toolkit importlib-metadata numexpr json5 pyqtchart attrs jupyterlab pygments gym nltk pywin32 ipykernel mistune sacremoses click scipy pandocfilters pyqt5-sip markupsafe brotlipy jsonschema jedi jupyter_client sqlite chardet gitdb ipywidgets joblib python-graphviz pyrsistent pyqt entrypoints pyparsing urllib3 testpath colorama argon2-cffi six typing_extensions pywinpty:   2%|2         | 5/219 [00:16<13:46,  3.86s/it]
# Examining conflict for jupyterlab_server ipywidgets jupyterlab nbclassic jupyter notebook ipykernel nbconvert nbdime widgetsnbextension qtconsole jupyter_client nbclient jupyter_server jupyter_console:   2%|2         | 5/219 [00:27<13:46,  3.86s/it]
# Examining conflict for jupyterlab_server ipywidgets jupyterlab nbclassic jupyter notebook ipykernel nbconvert nbdime widgetsnbextension qtconsole jupyter_client nbclient jupyter_server jupyter_console:   3%|2         | 6/219 [00:27<22:28,  6.33s/it]
# Examining conflict for nbclassic filelock pandas transformers traitlets requests prometheus_client scikit-learn packaging jupyter_server setuptools wcwidth jupyterlab_pygments decorator nbconvert prompt-toolkit jupyter_console sniffio send2trash anyio regex win_inet_pton backcall tokenizers pyzmq nbclient pyqt-impl pyqtwebengine dataclasses matplotlib-base jupyterlab_widgets terminado pysocks py-opencv pycparser notebook cryptography idna kiwisolver cycler bleach qt backports pyopengl olefile ipython zipp pyglet jupyterlab_server webencodings nbformat jupyter_core python smmap tornado cffi openssl pickleshare matplotlib jupyter wheel nbdime parso defusedxml qtconsole async_generator python_abi pyopenssl gitpython qtpy threadpoolctl future websocket-client certifi backports.functools_lru_cache widgetsnbextension ftfy box2d-py requests-unixsocket jinja2 ipython_genutils numpy pytz cloudpickle python-dateutil pip libopencv nest-asyncio py-xgboost babel atari_py tqdm pillow prompt_toolkit importlib-metadata numexpr json5 pyqtchart attrs jupyterlab pygments gym nltk pywin32 ipykernel mistune sacremoses click scipy pandocfilters pyqt5-sip markupsafe brotlipy jsonschema jedi jupyter_client chardet gitdb ipywidgets joblib python-graphviz pyrsistent pyqt entrypoints pyparsing urllib3 testpath colorama argon2-cffi six typing_extensions pywinpty:   3%|2         | 6/219 [00:29<22:28,  6.33s/it]
# Examining conflict for nbclassic filelock pandas transformers traitlets requests prometheus_client scikit-learn packaging jupyter_server setuptools wcwidth jupyterlab_pygments decorator nbconvert prompt-toolkit jupyter_console sniffio send2trash anyio regex win_inet_pton backcall tokenizers pyzmq nbclient pyqt-impl pyqtwebengine dataclasses matplotlib-base jupyterlab_widgets terminado pysocks py-opencv pycparser notebook cryptography idna kiwisolver cycler bleach qt backports pyopengl olefile ipython zipp pyglet jupyterlab_server webencodings nbformat jupyter_core python smmap tornado cffi openssl pickleshare matplotlib jupyter wheel nbdime parso defusedxml qtconsole async_generator python_abi pyopenssl gitpython qtpy threadpoolctl future websocket-client certifi backports.functools_lru_cache widgetsnbextension ftfy box2d-py requests-unixsocket jinja2 ipython_genutils numpy pytz cloudpickle python-dateutil pip libopencv nest-asyncio py-xgboost babel atari_py tqdm pillow prompt_toolkit importlib-metadata numexpr json5 pyqtchart attrs jupyterlab pygments gym nltk pywin32 ipykernel mistune sacremoses click scipy pandocfilters pyqt5-sip markupsafe brotlipy jsonschema jedi jupyter_client chardet gitdb ipywidgets joblib python-graphviz pyrsistent pyqt entrypoints pyparsing urllib3 testpath colorama argon2-cffi six typing_extensions pywinpty:   3%|3         | 7/219 [00:29<17:11,  4.86s/it]
# Examining conflict for nbclassic filelock transformers traitlets requests prometheus_client scikit-learn packaging jupyter_server setuptools wcwidth jupyterlab_pygments decorator nbconvert prompt-toolkit xz jupyter_console sniffio send2trash anyio regex win_inet_pton backcall pyzmq nbclient lcms2 dataclasses matplotlib-base jupyterlab_widgets terminado pysocks pycparser notebook cryptography idna kiwisolver cycler bleach backports pyopengl olefile zipp pyglet jupyterlab_server webencodings nbformat jupyter_core python smmap tornado cffi pickleshare libgd jupyter wheel nbdime parso defusedxml qtconsole async_generator python_abi pyopenssl gitpython qtpy threadpoolctl future websocket-client certifi backports.functools_lru_cache widgetsnbextension ftfy box2d-py requests-unixsocket jinja2 ipython_genutils numpy pytz cloudpickle python-dateutil pip libopencv nest-asyncio babel libtiff atari_py tqdm pillow prompt_toolkit importlib-metadata numexpr json5 openjpeg attrs jupyterlab pygments pywin32 nltk mistune sacremoses click pandocfilters markupsafe brotlipy jsonschema zstd jedi jupyter_client chardet gitdb ipywidgets joblib python-graphviz pyrsistent entrypoints pyparsing urllib3 testpath colorama argon2-cffi six typing_extensions pywinpty:   3%|3         | 7/219 [00:40<17:11,  4.86s/it]
# Examining conflict for nbclassic filelock transformers traitlets requests prometheus_client scikit-learn packaging jupyter_server setuptools wcwidth jupyterlab_pygments decorator nbconvert prompt-toolkit xz jupyter_console sniffio send2trash anyio regex win_inet_pton backcall pyzmq nbclient lcms2 dataclasses matplotlib-base jupyterlab_widgets terminado pysocks pycparser notebook cryptography idna kiwisolver cycler bleach backports pyopengl olefile zipp pyglet jupyterlab_server webencodings nbformat jupyter_core python smmap tornado cffi pickleshare libgd jupyter wheel nbdime parso defusedxml qtconsole async_generator python_abi pyopenssl gitpython qtpy threadpoolctl future websocket-client certifi backports.functools_lru_cache widgetsnbextension ftfy box2d-py requests-unixsocket jinja2 ipython_genutils numpy pytz cloudpickle python-dateutil pip libopencv nest-asyncio babel libtiff atari_py tqdm pillow prompt_toolkit importlib-metadata numexpr json5 openjpeg attrs jupyterlab pygments pywin32 nltk mistune sacremoses click pandocfilters markupsafe brotlipy jsonschema zstd jedi jupyter_client chardet gitdb ipywidgets joblib python-graphviz pyrsistent entrypoints pyparsing urllib3 testpath colorama argon2-cffi six typing_extensions pywinpty:   4%|3         | 8/219 [00:40<24:03,  6.84s/it]
# Examining conflict for nbclassic filelock pandas transformers traitlets requests prometheus_client scikit-learn packaging jupyter_server icu pthread-stubs setuptools jupyterlab_pygments decorator wcwidth nbconvert graphviz prompt-toolkit xz jupyter_console sniffio send2trash anyio regex jasper win_inet_pton backcall tokenizers pyzmq nbclient lcms2 lerc harfbuzz libsodium pyqt-impl pyqtwebengine dataclasses xorg-libxpm zlib expat matplotlib-base jupyterlab_widgets jpeg terminado pysocks py-opencv pycparser notebook xorg-libxt cryptography idna winpty gettext kiwisolver libdeflate cycler pcre bleach qt backports ffmpeg pyopengl olefile ipython xorg-libx11 libprotobuf zipp pyglet xorg-libxau gts jupyterlab_server tbb webencodings libclang jupyter_core python libiconv nbformat smmap freeglut tornado cffi openssl pickleshare matplotlib libgd jupyter zeromq wheel nbdime parso defusedxml qtconsole pixman async_generator python_abi libxgboost pyopenssl xorg-libxdmcp xorg-libice gitpython freetype qtpy threadpoolctl lz4-c future websocket-client certifi backports.functools_lru_cache libxcb libwebp-base widgetsnbextension ftfy box2d-py requests-unixsocket pango jinja2 ipython_genutils numpy jbig pytz cloudpickle python-dateutil pip libopencv nest-asyncio py-xgboost babel libpng fribidi atari_py libtiff opencv tqdm pillow mkl cairo prompt_toolkit importlib-metadata numexpr json5 pyqtchart fontconfig openjpeg attrs jupyterlab pygments gym nltk pywin32 ipykernel mistune sacremoses click scipy libglib libxml2 pandocfilters libffi xorg-libsm pyqt5-sip markupsafe brotlipy jsonschema tk zstd jedi jupyter_client libwebp sqlite vc xorg-libxext chardet gitdb ipywidgets joblib python-graphviz pyrsistent pyqt entrypoints pyparsing urllib3 testpath graphite2 colorama argon2-cffi getopt-win32 six libblas typing_extensions pywinpty:   4%|3         | 8/219 [00:48<24:03,  6.84s/it]
# Examining conflict for nbclassic filelock pandas transformers traitlets requests prometheus_client scikit-learn packaging jupyter_server icu pthread-stubs setuptools jupyterlab_pygments decorator wcwidth nbconvert graphviz prompt-toolkit xz jupyter_console sniffio send2trash anyio regex jasper win_inet_pton backcall tokenizers pyzmq nbclient lcms2 lerc harfbuzz libsodium pyqt-impl pyqtwebengine dataclasses xorg-libxpm zlib expat matplotlib-base jupyterlab_widgets jpeg terminado pysocks py-opencv pycparser notebook xorg-libxt cryptography idna winpty gettext kiwisolver libdeflate cycler pcre bleach qt backports ffmpeg pyopengl olefile ipython xorg-libx11 libprotobuf zipp pyglet xorg-libxau gts jupyterlab_server tbb webencodings libclang jupyter_core python libiconv nbformat smmap freeglut tornado cffi openssl pickleshare matplotlib libgd jupyter zeromq wheel nbdime parso defusedxml qtconsole pixman async_generator python_abi libxgboost pyopenssl xorg-libxdmcp xorg-libice gitpython freetype qtpy threadpoolctl lz4-c future websocket-client certifi backports.functools_lru_cache libxcb libwebp-base widgetsnbextension ftfy box2d-py requests-unixsocket pango jinja2 ipython_genutils numpy jbig pytz cloudpickle python-dateutil pip libopencv nest-asyncio py-xgboost babel libpng fribidi atari_py libtiff opencv tqdm pillow mkl cairo prompt_toolkit importlib-metadata numexpr json5 pyqtchart fontconfig openjpeg attrs jupyterlab pygments gym nltk pywin32 ipykernel mistune sacremoses click scipy libglib libxml2 pandocfilters libffi xorg-libsm pyqt5-sip markupsafe brotlipy jsonschema tk zstd jedi jupyter_client libwebp sqlite vc xorg-libxext chardet gitdb ipywidgets joblib python-graphviz pyrsistent pyqt entrypoints pyparsing urllib3 testpath graphite2 colorama argon2-cffi getopt-win32 six libblas typing_extensions pywinpty:   4%|4         | 9/219 [00:48<24:31,  7.01s/it]
# Examining conflict for jupyterlab_server send2trash jupyterlab nbclassic jupyter notebook nbdime widgetsnbextension jupyter_server:   4%|4         | 9/219 [00:59<24:31,  7.01s/it]
# Examining conflict for jupyterlab_server send2trash jupyterlab nbclassic jupyter notebook nbdime widgetsnbextension jupyter_server:   5%|4         | 10/219 [00:59<29:32,  8.48s/it]
# ...
# Examining conflict for opencv libgd py-opencv libwebp-base graphviz libwebp libopencv:  66%|######5   | 144/219 [05:02<00:31,  2.41it/s]
# Examining conflict for opencv libgd py-opencv libwebp-base graphviz libwebp libopencv:  66%|######6   | 145/219 [05:02<00:20,  3.60it/s]
# Examining conflict for pango fribidi graphviz:  66%|######6   | 145/219 [05:05<00:20,  3.60it/s]
# Examining conflict for pango fribidi graphviz:  67%|######6   | 146/219 [05:05<01:01,  1.19it/s]
# Examining conflict for libtiff openjpeg opencv libgd py-opencv qt pyqt pillow jasper graphviz matplotlib-base jpeg libopencv lcms2 pyqt-impl pyqtwebengine pyqtchart:  67%|######6   | 146/219 [05:05<01:01,  1.19it/s]
# Examining conflict for matplotlib fontconfig libopencv libgd py-opencv opencv gym nltk pillow matplotlib-base graphviz cairo freetype pango pyglet harfbuzz:  67%|######7   | 147/219 [05:09<01:00,  1.19it/s]
# Examining conflict for matplotlib fontconfig libopencv libgd py-opencv opencv gym nltk pillow matplotlib-base graphviz cairo freetype pango pyglet harfbuzz:  68%|######7   | 148/219 [05:09<01:29,  1.26s/it]
# Examining conflict for gts graphviz cairo libglib pango gettext harfbuzz:  68%|######7   | 148/219 [05:13<01:29,  1.26s/it]
# Examining conflict for gts graphviz cairo libglib pango gettext harfbuzz:  68%|######8   | 149/219 [05:13<02:13,  1.91s/it]
# Examining conflict for libgd xorg-libxpm graphviz:  68%|######8   | 149/219 [05:14<02:13,  1.91s/it]
# Examining conflict for libgd xorg-libxpm graphviz:  68%|######8   | 150/219 [05:14<01:44,  1.51s/it]
# Examining conflict for gts graphviz python-graphviz:  68%|######8   | 150/219 [05:14<01:44,  1.51s/it]
# Examining conflict for pcre gts graphviz cairo libglib pango harfbuzz:  69%|######8   | 151/219 [05:14<01:42,  1.51s/it]
# Examining conflict for python-graphviz graphviz cairo pango harfbuzz:  69%|######9   | 152/219 [05:14<01:41,  1.51s/it]
# Examining conflict for python-graphviz graphviz cairo pango harfbuzz:  70%|######9   | 153/219 [05:14<00:53,  1.24it/s]
# Examining conflict for fontconfig libgd graphviz cairo pango harfbuzz:  70%|######9   | 153/219 [05:14<00:53,  1.24it/s]
# Examining conflict for ipywidgets jupyterlab ipykernel ipython prompt_toolkit prompt-toolkit jupyter_console:  70%|#######   | 154/219 [05:14<00:52,  1.24it/s]
# Examining conflict for ipywidgets jupyterlab ipykernel ipython prompt_toolkit prompt-toolkit jupyter_console:  71%|#######   | 155/219 [05:14<00:36,  1.74it/s]
# Examining conflict for jupyter jupyter_console:  71%|#######   | 155/219 [05:15<00:36,  1.74it/s]
# Examining conflict for jupyter jupyter_console:  71%|#######1  | 156/219 [05:15<00:39,  1.62it/s]
# Examining conflict for ipywidgets jupyterlab jupyter ipykernel prompt_toolkit jupyter_console:  71%|#######1  | 156/219 [05:15<00:39,  1.62it/s]
# Examining conflict for ipywidgets jupyterlab jupyter ipykernel jupyter_console:  72%|#######1  | 157/219 [05:16<00:38,  1.62it/s]
# Examining conflict for ipywidgets jupyterlab jupyter ipykernel jupyter_console:  72%|#######2  | 158/219 [05:16<00:33,  1.83it/s]
# Examining conflict for ipywidgets jupyterlab ipykernel ipython jedi jupyter_console:  72%|#######2  | 158/219 [05:16<00:33,  1.83it/s]
# Examining conflict for ipywidgets jupyterlab ipykernel ipython jedi jupyter_console:  73%|#######2  | 159/219 [05:16<00:33,  1.77it/s]
# Examining conflict for ipywidgets ipykernel jupyterlab jupyter_console:  73%|#######2  | 159/219 [05:17<00:33,  1.77it/s]
# Examining conflict for ipywidgets ipykernel jupyterlab jupyter_console:  73%|#######3  | 160/219 [05:17<00:34,  1.69it/s]
# Examining conflict for ipywidgets jupyterlab ipykernel ipython backcall jupyter_console:  73%|#######3  | 160/219 [05:18<00:34,  1.69it/s]
# Examining conflict for ipywidgets jupyterlab ipykernel ipython backcall jupyter_console:  74%|#######3  | 161/219 [05:18<00:38,  1.51it/s]
# Examining conflict for ipywidgets jupyterlab ipykernel jupyter_console ipython pickleshare:  74%|#######3  | 161/219 [05:19<00:38,  1.51it/s]
# Examining conflict for ipywidgets jupyterlab ipykernel jupyter_console ipython pickleshare:  74%|#######3  | 162/219 [05:19<00:37,  1.52it/s]
# Examining conflict for sniffio anyio:  74%|#######3  | 162/219 [05:19<00:37,  1.52it/s]
# Examining conflict for sniffio anyio:  74%|#######4  | 163/219 [05:19<00:36,  1.53it/s]
# Examining conflict for anyio jsonschema gitpython typing_extensions importlib-metadata:  74%|#######4  | 163/219 [05:19<00:36,  1.53it/s]
# Examining conflict for attrs anyio:  75%|#######4  | 164/219 [05:19<00:36,  1.53it/s]
# Examining conflict for attrs anyio:  75%|#######5  | 165/219 [05:19<00:23,  2.30it/s]
# Examining conflict for libopencv opencv py-opencv jasper:  75%|#######5  | 165/219 [05:20<00:23,  2.30it/s]
# Examining conflict for freeglut libopencv jasper:  76%|#######5  | 166/219 [05:22<00:22,  2.30it/s]
# Examining conflict for freeglut libopencv jasper:  76%|#######6  | 167/219 [05:22<00:38,  1.34it/s]
# Examining conflict for urllib3 pysocks win_inet_pton:  76%|#######6  | 167/219 [05:22<00:38,  1.34it/s]
# Examining conflict for urllib3 pysocks win_inet_pton:  77%|#######6  | 168/219 [05:22<00:33,  1.50it/s]
# Examining conflict for fonts-conda-ecosystem font-ttf-ubuntu fonts-conda-forge:  77%|#######6  | 168/219 [05:22<00:33,  1.50it/s]
# Examining conflict for fonts-conda-ecosystem fonts-conda-forge font-ttf-inconsolata:  77%|#######7  | 169/219 [05:22<00:33,  1.50it/s]
# Examining conflict for fonts-conda-ecosystem cairo pango libgd:  78%|#######7  | 170/219 [05:22<00:32,  1.50it/s]
# Examining conflict for fonts-conda-forge libgd fonts-conda-ecosystem cairo pango:  78%|#######8  | 171/219 [05:23<00:31,  1.50it/s]
# Examining conflict for fonts-conda-forge libgd fonts-conda-ecosystem cairo pango:  79%|#######8  | 172/219 [05:23<00:15,  3.06it/s]
# Examining conflict for fonts-conda-ecosystem fonts-conda-forge font-ttf-source-code-pro:  79%|#######8  | 172/219 [05:23<00:15,  3.06it/s]
# Examining conflict for fonts-conda-ecosystem fonts-conda-forge font-ttf-source-code-pro:  79%|#######8  | 173/219 [05:23<00:13,  3.40it/s]
# Examining conflict for fonts-conda-ecosystem fonts-conda-forge font-ttf-dejavu-sans-mono:  79%|#######8  | 173/219 [05:23<00:13,  3.40it/s]
# Examining conflict for lcms2 pillow matplotlib-base:  79%|#######9  | 174/219 [05:23<00:13,  3.40it/s]
# Examining conflict for libtiff openjpeg libgd zstd pillow libopencv lcms2:  80%|#######9  | 175/219 [05:23<00:12,  3.40it/s]
# Examining conflict for libtiff openjpeg libgd zstd pillow libopencv lcms2:  80%|########  | 176/219 [05:23<00:11,  3.85it/s]
# Examining conflict for libtiff openjpeg libgd jbig pillow libopencv lcms2:  80%|########  | 176/219 [05:24<00:11,  3.85it/s]
# Examining conflict for libtiff openjpeg libgd jbig pillow libopencv lcms2:  81%|########  | 177/219 [05:24<00:12,  3.31it/s]
# Examining conflict for libtiff openjpeg libgd pillow libopencv lcms2 lerc:  81%|########  | 177/219 [05:24<00:12,  3.31it/s]
# Examining conflict for libtiff openjpeg libgd pillow libopencv lcms2 lerc:  81%|########1 | 178/219 [05:24<00:13,  2.96it/s]
# Examining conflict for libtiff openjpeg libgd pillow libopencv lcms2 libdeflate:  81%|########1 | 178/219 [05:25<00:13,  2.96it/s]
# Examining conflict for libtiff openjpeg libgd pillow libopencv lcms2 libdeflate:  82%|########1 | 179/219 [05:25<00:15,  2.67it/s]
# Examining conflict for gts cairo pango harfbuzz:  82%|########1 | 179/219 [05:25<00:15,  2.67it/s]
# Examining conflict for gts cairo pango harfbuzz:  82%|########2 | 180/219 [05:25<00:16,  2.43it/s]
# Examining conflict for pango graphite2 harfbuzz:  82%|########2 | 180/219 [05:26<00:16,  2.43it/s]
# Examining conflict for pango graphite2 harfbuzz:  83%|########2 | 181/219 [05:26<00:13,  2.78it/s]
# Examining conflict for matplotlib pyqt qtconsole pyqt-impl pyqtwebengine pyqtchart:  83%|########2 | 181/219 [05:26<00:13,  2.78it/s]
# Examining conflict for matplotlib pyqt5-sip pyqt qtconsole pyqt-impl pyqtwebengine pyqtchart:  83%|########3 | 182/219 [05:26<00:13,  2.78it/s]
# Examining conflict for matplotlib pyqt5-sip pyqt qtconsole pyqt-impl pyqtwebengine pyqtchart:  84%|########3 | 183/219 [05:26<00:10,  3.30it/s]
# Examining conflict for qt libclang pyqt libopencv pyqt-impl pyqtwebengine pyqtchart:  84%|########3 | 183/219 [05:26<00:10,  3.30it/s]
# Examining conflict for qt libclang pyqt libopencv pyqt-impl pyqtwebengine pyqtchart:  84%|########4 | 184/219 [05:26<00:11,  3.02it/s]
# Examining conflict for matplotlib opencv py-opencv qt pyqt qtconsole libopencv pyqt-impl pyqtwebengine pyqtchart:  84%|########4 | 184/219 [05:27<00:11,  3.02it/s]
# Examining conflict for matplotlib opencv py-opencv qt pyqt qtconsole libopencv pyqt-impl pyqtwebengine pyqtchart:  84%|########4 | 185/219 [05:27<00:13,  2.53it/s]
# Examining conflict for matplotlib qtconsole pyqt pyqtwebengine:  84%|########4 | 185/219 [05:30<00:13,  2.53it/s]
# Examining conflict for matplotlib qtconsole pyqt pyqtwebengine:  85%|########4 | 186/219 [05:30<00:36,  1.11s/it]
# Examining conflict for libgd xorg-libxpm:  85%|########4 | 186/219 [05:31<00:36,  1.11s/it]
# Examining conflict for libgd xorg-libxpm:  85%|########5 | 187/219 [05:31<00:28,  1.11it/s]
# Examining conflict for libgd xorg-libxpm xorg-libx11 xorg-libxt xorg-libxext:  85%|########5 | 187/219 [05:31<00:28,  1.11it/s]
# Examining conflict for xorg-libx11 xorg-libxext xorg-libxpm xorg-libxt:  86%|########5 | 188/219 [05:31<00:27,  1.11it/s]
# Examining conflict for libgd xorg-libxpm xorg-libxt:  86%|########6 | 189/219 [05:31<00:27,  1.11it/s]
# Examining conflict for xorg-libxext libgd xorg-libxpm:  87%|########6 | 190/219 [05:31<00:26,  1.11it/s]
# Examining conflict for xorg-libsm xorg-libxpm xorg-libxt:  87%|########7 | 191/219 [05:31<00:25,  1.11it/s]
# Examining conflict for xorg-libsm xorg-libxpm xorg-libxt:  88%|########7 | 192/219 [05:31<00:08,  3.11it/s]
# Examining conflict for xorg-libxpm xorg-libxt xorg-libx11 xorg-kbproto xorg-libxext:  88%|########7 | 192/219 [05:31<00:08,  3.11it/s]
# Examining conflict for xorg-xproto libgd xorg-libxpm xorg-libx11 xorg-libxt xorg-libxext:  88%|########8 | 193/219 [05:31<00:08,  3.11it/s]
# Examining conflict for xorg-libxext libgd xorg-libxpm xorg-xextproto:  89%|########8 | 194/219 [05:31<00:08,  3.11it/s]
# Examining conflict for xorg-libice xorg-libsm xorg-libxpm xorg-libxt:  89%|########9 | 195/219 [05:31<00:07,  3.11it/s]
# Examining conflict for xorg-libxpm libxcb xorg-libx11 xorg-libxt xorg-libxext:  89%|########9 | 196/219 [05:31<00:07,  3.11it/s]
# Examining conflict for matplotlib nltk matplotlib-base:  90%|########9 | 197/219 [05:31<00:07,  3.11it/s]
# Examining conflict for openjpeg pillow matplotlib-base:  90%|######### | 198/219 [05:31<00:06,  3.11it/s]
# Examining conflict for openjpeg pillow matplotlib-base:  91%|######### | 199/219 [05:31<00:03,  5.57it/s]
# Examining conflict for cycler matplotlib nltk matplotlib-base:  91%|######### | 199/219 [05:32<00:03,  5.57it/s]
# Examining conflict for matplotlib pillow matplotlib-base:  91%|#########1| 200/219 [05:32<00:03,  5.57it/s]
# Examining conflict for matplotlib pillow matplotlib-base:  92%|#########1| 201/219 [05:32<00:04,  4.08it/s]
# Examining conflict for matplotlib kiwisolver nltk matplotlib-base:  92%|#########1| 201/219 [05:32<00:04,  4.08it/s]
# Examining conflict for jupyterlab_server jsonschema nbformat nltk matplotlib-base:  92%|#########2| 202/219 [05:33<00:04,  4.08it/s]
# Examining conflict for jupyterlab_server jsonschema nbformat nltk matplotlib-base:  93%|#########2| 203/219 [05:33<00:04,  3.21it/s]
# Examining conflict for olefile pillow matplotlib-base:  93%|#########2| 203/219 [05:34<00:04,  3.21it/s]
# Examining conflict for olefile pillow matplotlib-base:  93%|#########3| 204/219 [05:34<00:05,  2.94it/s]
# Examining conflict for ipywidgets jupyterlab_widgets jupyter:  93%|#########3| 204/219 [05:34<00:05,  2.94it/s]
# Examining conflict for ipywidgets jupyterlab_widgets jupyter:  94%|#########3| 205/219 [05:34<00:05,  2.60it/s]
# Examining conflict for winpty terminado pywinpty:  94%|#########3| 205/219 [05:35<00:05,  2.60it/s]
# Examining conflict for winpty terminado pywinpty:  94%|#########4| 206/219 [05:35<00:04,  2.94it/s]
# Examining conflict for terminado pywinpty:  94%|#########4| 206/219 [05:35<00:04,  2.94it/s]
# Examining conflict for liblapack numpy libblas scipy libcblas liblapacke:  95%|#########4| 207/219 [05:35<00:04,  2.94it/s]
# Examining conflict for liblapack numpy libblas scipy libcblas liblapacke:  95%|#########4| 208/219 [05:35<00:02,  4.06it/s]
# Examining conflict for opencv py-opencv:  95%|#########4| 208/219 [05:35<00:02,  4.06it/s]
# Examining conflict for opencv py-opencv:  95%|#########5| 209/219 [05:35<00:03,  2.87it/s]
# Examining conflict for libopencv opencv py-opencv:  95%|#########5| 209/219 [05:36<00:03,  2.87it/s]
# Examining conflict for libopencv opencv py-opencv:  96%|#########5| 210/219 [05:36<00:03,  2.54it/s]
# Examining conflict for libopencv libprotobuf opencv py-opencv:  96%|#########5| 210/219 [05:39<00:03,  2.54it/s]
# Examining conflict for libopencv libprotobuf opencv py-opencv:  96%|#########6| 211/219 [05:39<00:07,  1.13it/s]
# Examining conflict for libopencv opencv py-opencv liblapacke:  96%|#########6| 211/219 [05:41<00:07,  1.13it/s]
# Examining conflict for libopencv opencv py-opencv liblapacke:  97%|#########6| 212/219 [05:41<00:09,  1.37s/it]
# Examining conflict for argon2-cffi pycparser brotlipy cryptography cffi:  97%|#########6| 212/219 [05:44<00:09,  1.37s/it]
# Examining conflict for argon2-cffi pycparser brotlipy cryptography cffi:  97%|#########7| 213/219 [05:44<00:10,  1.77s/it]
# Examining conflict for cryptography argon2-cffi cffi brotlipy:  97%|#########7| 213/219 [05:44<00:10,  1.77s/it]
# Examining conflict for cryptography argon2-cffi cffi brotlipy:  98%|#########7| 214/219 [05:44<00:06,  1.36s/it]
# Examining conflict for cryptography pyopenssl urllib3:  98%|#########7| 214/219 [05:45<00:06,  1.36s/it]
# Examining conflict for cryptography pyopenssl urllib3:  98%|#########8| 215/219 [05:45<00:04,  1.05s/it]
# Examining conflict for ffmpeg pyglet gym:  98%|#########8| 215/219 [05:45<00:04,  1.05s/it]
# Examining conflict for ffmpeg pyglet gym:  99%|#########8| 216/219 [05:45<00:02,  1.20it/s]
# Examining conflict for parso jedi ipython:  99%|#########8| 216/219 [05:45<00:02,  1.20it/s]
# Examining conflict for parso jedi ipython:  99%|#########9| 217/219 [05:45<00:01,  1.56it/s]
# Examining conflict for jedi ipython:  99%|#########9| 217/219 [05:45<00:01,  1.56it/s]
# Examining conflict for pickleshare ipython: 100%|#########9| 218/219 [05:45<00:00,  1.56it/s]
# Examining conflict for pickleshare ipython: 100%|##########| 219/219 [05:45<00:00,  2.66it/s]
# Examining conflict for libxcb xorg-libxdmcp xorg-libx11: 100%|##########| 219/219 [05:45<00:00,  2.66it/s]
# Examining conflict for libxcb xorg-libxau xorg-libx11: : 220it [05:45,  2.66it/s]
# Examining conflict for jsonschema ipykernel click zipp importlib-metadata: : 221it [05:45,  2.66it/s]
# Examining conflict for importlib-metadata zipp: : 222it [05:46,  2.66it/s]
# Examining conflict for importlib-metadata zipp: : 223it [05:46,  4.50it/s]
# Examining conflict for pyglet gym: : 223it [05:46,  4.50it/s]

# %%
# Setup code and import libraries
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re as re
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)
pd.options.display.max_rows = 6
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b61f0ad5e455> in <module>
#       1 # Setup code and import libraries
# ----> 2 from bs4 import BeautifulSoup
#       3 import numpy as np
#       4 import pandas as pd
#       5 import re as re
#
# ModuleNotFoundError: No module named 'bs4'

# %% [markdown]
# There are two ways we can extract these resources. One is to extract the data manually (static and dynamic pages). The second is to use a provided interface (APIs, but could apply to all 3 web resource variants). We will be focusing mainly on manual extraction in this section.
#
# First, we can use a library to access the resource and make a request.

# %%
import requests
r = requests.get('https://raw.githubusercontent.com/openmundi/world.csv/master/countries(249)_alpha2.csv', verify=False)
r.text[0:140]
# Out:
# Examining conflict for pyglet gym: : 224it [05:46,  4.85it/s]
# Examining conflict for pyglet future gym: : 224it [05:46,  4.85it/s]
# Examining conflict for jupyterlab_server jupyterlab: : 225it [05:46,  4.85it/s]
# Examining conflict for jupyterlab_server jupyterlab: : 226it [05:46,  6.00it/s]
# Examining conflict for jupyterlab_server nbformat ipykernel jsonschema: : 226it [05:46,  6.00it/s]
# Examining conflict for jupyterlab_server nbformat ipykernel jsonschema: : 227it [05:46,  5.28it/s]
# Examining conflict for jupyterlab_server nbformat jsonschema: : 227it [05:47,  5.28it/s]
# Examining conflict for jupyterlab_server nbformat jsonschema: : 228it [05:47,  4.54it/s]
# Examining conflict for jupyterlab_server nbformat jsonschema pyrsistent: : 228it [05:47,  4.54it/s]
# Examining conflict for jupyterlab_server nbformat jsonschema pyrsistent: : 229it [05:47,  4.80it/s]
# Examining conflict for jupyterlab_server jupyterlab json5: : 229it [05:47,  4.80it/s]
# Examining conflict for jupyterlab_server jupyterlab json5: : 230it [05:47,  4.56it/s]
# Examining conflict for jupyterlab_server jupyterlab babel: : 230it [05:47,  4.56it/s]
# Examining conflict for jupyterlab_server jupyterlab babel: : 231it [05:47,  4.20it/s]
# Examining conflict for tbb libblas mkl scipy numexpr: : 231it [05:48,  4.20it/s]
# Examining conflict for tbb libblas mkl scipy numexpr: : 232it [05:48,  3.98it/s]
# Examining conflict for pip python: : 232it [05:48,  3.98it/s]
# Examining conflict for pip python: : 233it [05:48,  2.92it/s]
# Examining conflict for gitpython nbdime smmap gitdb: : 233it [05:48,  2.92it/s]
# Examining conflict for testpath importlib-metadata pickleshare: : 234it [05:48,  2.92it/s]
# Examining conflict for testpath importlib-metadata pickleshare: : 235it [05:48,  4.39it/s]
# Examining conflict for _py-xgboost-mutex py-xgboost: : 235it [05:48,  4.39it/s]
# Examining conflict for _py-xgboost-mutex py-xgboost: : 236it [05:48,  4.95it/s]
# Examining conflict for matplotlib nltk: : 236it [05:48,  4.95it/s]
# Examining conflict for matplotlib qtconsole pyqt: : 237it [05:48,  4.95it/s]
# Examining conflict for matplotlib qtconsole pyqt pyqtchart: : 238it [05:49,  4.95it/s]
# Examining conflict for matplotlib qtconsole pyqt pyqtchart: : 239it [05:49,  6.25it/s]
# Examining conflict for matplotlib jupyter nltk pyqt qtconsole: : 239it [05:49,  6.25it/s]
# Examining conflict for matplotlib jupyter nltk pyqt qtconsole: : 240it [05:49,  5.04it/s]
# Examining conflict for fontconfig libgd cairo libxml2 pango: : 240it [05:50,  5.04it/s]
# Examining conflict for fontconfig libgd cairo libxml2 pango: : 241it [05:50,  3.26it/s]
# Examining conflict for ipywidgets widgetsnbextension jupyter: : 241it [05:50,  3.26it/s]
# Examining conflict for ipywidgets widgetsnbextension jupyter: : 242it [05:50,  3.76it/s]
# Examining conflict for qtconsole jupyter: : 242it [05:50,  3.76it/s]
# Examining conflict for qtconsole jupyter: : 243it [05:50,  4.26it/s]
# Examining conflict for ipywidgets jupyter: : 243it [05:50,  4.26it/s]
# Examining conflict for qtconsole qtpy jupyter: : 244it [05:50,  4.26it/s]
# Examining conflict for gitpython nbdime: : 245it [05:50,  4.26it/s]
# Examining conflict for gitpython nbdime: : 246it [05:50,  7.28it/s]
# Examining conflict for gitpython nbdime gitdb: : 246it [05:50,  7.28it/s]
# Examining conflict for libxgboost py-xgboost: : 247it [05:50,  7.28it/s]
# Examining conflict for libxgboost py-xgboost: : 248it [05:50,  8.95it/s]
# Examining conflict for libtiff lz4-c zstd: : 248it [05:51,  8.95it/s]
# Examining conflict for numpy libblas mkl scipy intel-openmp numexpr: : 249it [05:51,  8.95it/s]
# Examining conflict for numpy libblas mkl scipy intel-openmp numexpr: : 250it [05:51,  9.36it/s]
# Examining conflict for gym cloudpickle: : 250it [05:51,  9.36it/s]
# Examining conflict for libtiff zstd: : 251it [05:51,  9.36it/s]
# Examining conflict for libtiff zstd: : 252it [05:51,  5.15it/s]
# Examining conflict for click jsonschema ipykernel importlib-metadata: : 252it [05:51,  5.15it/s]
#
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - argon2-cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|>=3.5,<3.6.0a0|3.4.*|3.8.*|3.9.*|3.7.*|3.10.*',build='1_73_pypy|2_73_pypy|3_73_pypy|0_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|5_73_pypy|4_73_pypy|0_73_pypy']
#   - brotlipy -> python[version='3.10.*|3.4.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.7.*|3.9.*|3.8.*',build='1_73_pypy|2_73_pypy|3_73_pypy|0_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|5_73_pypy|4_73_pypy|0_73_pypy']
#   - cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|>=3.10,<3.11.0a0|>=3.7,<3.8.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0|>=3.6,<3.7.0a0|3.7.9|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9|>=3.5,<3.6.0a0|3.4.*',build='1_73_pypy|2_73_pypy|3_73_pypy|0_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|5_73_pypy|4_73_pypy|0_73_pypy']
#   - cryptography -> python[version='3.10.*|3.6.12|3.6.12|3.7.10|3.7.10|3.7.12|3.7.9|3.6.9|3.6.9|3.6.9|3.6.9|3.9.*|3.8.*|3.7.*|3.4.*|>=3.5|<=3.3',build='1_73_pypy|2_73_pypy|3_73_pypy|0_73_pypy|0_73_pypy|1_73_pypy|5_73_pypy|5_73_pypy|4_73_pypy|0_73_pypy']
#   - gitpython -> python[version='>=3.8,<3.9.0a0']
#   - jinja2 -> python[version='>=3.10,<3.11.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0']
#   - packaging -> python[version='>=3.8,<3.9.0a0|>=3.9,<3.10.0a0']
#   - prometheus_client -> python[version='>=3.8,<3.9.0a0|>=3.9,<3.10.0a0']
#   - py-xgboost=0.90 -> python[version='3.5.*|3.6.*|>=3.10,<3.11.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0|>=3.5,<3.6.0a0']
#   - pygments -> python[version='>=3.10,<3.11.0a0|>=3.8,<3.9.0a0|>=3.9,<3.10.0a0']
#   - pyopenssl -> python[version='>=3.10,<3.11.0a0|>=3.9,<3.10.0a0']
#   - python-dateutil -> python[version='>=3.8,<3.9.0a0|>=3.9,<3.10.0a0']
#   - requests-unixsocket -> python[version='2.7.*|3.5.*|3.6.*']
#   - testpath -> python[version='3.4.*|>=3.10,<3.11.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0']
#
# Your python: python=3.7
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# When python appears to the right, that indicates that the thing on the left is somehow
# not available for the python version you are constrained to. Note that conda will not
# change your python version to a different minor version unless you explicitly specify
# that.
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package cryptography conflicts for:
# urllib3 -> cryptography[version='>=1.3.4']
# requests-unixsocket -> urllib3[version='>=1.8,<2'] -> cryptography[version='>=1.3.4']
# requests=2.25 -> urllib3[version='>=1.21.1,<1.27'] -> cryptography[version='>=1.3.4']
# urllib3 -> pyopenssl[version='>=0.14'] -> cryptography[version='>=1.3|>=1.9|>=2.1.4|>=2.2.1|>=2.8|>=3.2|>=3.3']
# prometheus_client -> twisted -> cryptography[version='>=1.5|>=2.6']
# pyopenssl -> cryptography[version='>=1.3|>=1.3.4|>=1.9|>=2.1.4|>=2.2.1|>=2.8|>=3.2|>=3.3']
#
# Package bzip2 conflicts for:
# urllib3 -> python[version='<4.0'] -> bzip2[version='>=1.0.8,<2.0a0']
# scikit-learn=0.24 -> pypy3.7[version='>=7.3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# click -> pypy3.7[version='>=7.3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# tqdm=4.56 -> python[version='>=2.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# joblib=0.14 -> python -> bzip2[version='>=1.0.8,<2.0a0']
# requests=2.25 -> python -> bzip2[version='>=1.0.8,<2.0a0']
# pygments -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# certifi -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# matplotlib-base -> pypy3.7[version='>=7.3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# chardet -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# python=3.7 -> pypy3.7=7.3.7 -> bzip2[version='>=1.0.8,<2.0a0']
# brotlipy -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# nbclassic -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# qtpy -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# filelock -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# cycler -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# dataclasses -> python[version='>=3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyterlab_pygments -> python -> bzip2[version='>=1.0.8,<2.0a0']
# traitlets -> python[version='>=3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# zipp -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# pytz -> python[version='>=3'] -> bzip2[version='>=1.0.8,<2.0a0']
# pyglet=1.5 -> pypy3.7[version='>=7.3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# backports -> python -> bzip2[version='>=1.0.8,<2.0a0']
# argon2-cffi -> pypy3.7[version='>=7.3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# ipython_genutils -> python -> bzip2[version='>=1.0.8,<2.0a0']
# win_inet_pton -> pypy3.7[version='>=7.3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# ftfy=5.8 -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# cloudpickle -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# defusedxml -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# decorator -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# attrs -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*'] -> bzip2[version='>=1.0.8,<2.0a0']
# pywin32 -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pycparser -> python[version='=2.7|>=3.4'] -> bzip2[version='>=1.0.8,<2.0a0']
# cryptography -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# terminado -> pypy3.7[version='>=7.3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# ipywidgets=7.6 -> python[version='>=3.3'] -> bzip2[version='>=1.0.8,<2.0a0']
# parso -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# send2trash -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# backcall -> python -> bzip2[version='>=1.0.8,<2.0a0']
# jinja2 -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# six -> python -> bzip2[version='>=1.0.8,<2.0a0']
# nltk=3.4 -> python -> bzip2[version='>=1.0.8,<2.0a0']
# qtconsole -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# wcwidth -> python -> bzip2[version='>=1.0.8,<2.0a0']
# babel -> python -> bzip2[version='>=1.0.8,<2.0a0']
# async_generator -> python[version='>2.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# prompt_toolkit -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# cffi -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter_server -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# entrypoints -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# pyzmq -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# websocket-client -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# box2d-py=2.3 -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter_client -> python[version='>=3.6.1'] -> bzip2[version='>=1.0.8,<2.0a0']
# nest-asyncio -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# webencodings -> python -> bzip2[version='>=1.0.8,<2.0a0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> bzip2[version='>=1.0.8,<2.0a0']
# python-dateutil -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# notebook -> python[version='>=3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# mistune -> pypy3.7[version='>=7.3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# python-graphviz -> python[version='>=3'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter=1.0 -> python -> bzip2[version='>=1.0.8,<2.0a0']
# atari_py=0.2 -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# olefile -> python -> bzip2[version='>=1.0.8,<2.0a0']
# prompt-toolkit -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# pip -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# jsonschema -> python[version='>=3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# widgetsnbextension=3.5 -> python -> bzip2[version='>=1.0.8,<2.0a0']
# threadpoolctl -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# bleach -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# smmap -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# pyparsing -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# testpath -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyterlab_widgets -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# colorama -> python -> bzip2[version='>=1.0.8,<2.0a0']
# typing_extensions -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# nbconvert -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# nbformat -> python[version='>=3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter_console -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# tornado -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# anyio -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# importlib-metadata -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# pywinpty -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# numexpr=2.7 -> pypy3.7[version='>=7.3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# sniffio -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# nbclient -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# python_abi -> python=3.10 -> bzip2[version='>=1.0.8,<2.0a0']
# json5 -> python -> bzip2[version='>=1.0.8,<2.0a0']
# setuptools -> pypy3.7[version='>=7.3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# future -> pypy3.7[version='>=7.3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyterlab -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# numpy=1.19 -> pypy3.7[version='>=7.3.5'] -> bzip2[version='>=1.0.8,<2.0a0']
# jedi -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# transformers=4.3 -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# packaging -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# pysocks -> pypy3.7[version='>=7.3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# pyrsistent -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# requests-unixsocket -> python -> bzip2[version='>=1.0.8,<2.0a0']
# pyopengl=3.1 -> python -> bzip2[version='>=1.0.8,<2.0a0']
# pyopenssl -> python[version='>=2.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyterlab_server -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# jupyter_core -> python -> bzip2[version='>=1.0.8,<2.0a0']
# gitpython -> python[version='>=3.7'] -> bzip2[version='>=1.0.8,<2.0a0']
# regex -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# markupsafe -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# gitdb -> python[version='>=3.4'] -> bzip2[version='>=1.0.8,<2.0a0']
# pickleshare -> python[version='>=3'] -> bzip2[version='>=1.0.8,<2.0a0']
# sacremoses -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# wheel -> python[version='!=3.0,!=3.1,!=3.2,!=3.3,!=3.4'] -> bzip2[version='>=1.0.8,<2.0a0']
# kiwisolver -> python[version='>=3.10,<3.11.0a0'] -> bzip2[version='>=1.0.8,<2.0a0']
# backports.functools_lru_cache -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# nbdime=2.1 -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# prometheus_client -> python[version='>=3.6'] -> bzip2[version='>=1.0.8,<2.0a0']
# idna -> python -> bzip2[version='>=1.0.8,<2.0a0']
#
# Package openblas conflicts for:
# transformers=4.3 -> numpy -> openblas[version='0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0']
# py-xgboost=0.90 -> numpy -> openblas[version='0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0']
# numexpr=2.7 -> numpy[version='>=1.14.6,<2.0a0'] -> openblas[version='0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0']
# numpy=1.19 -> libblas[version='>=3.8.0,<4.0a0'] -> openblas[version='0.3.5.*|0.3.6|>=0.3.6,<0.3.7.0a0',build=h828a276_2]
# scipy=1.6 -> libblas[version='>=3.8.0,<4.0a0'] -> openblas[version='0.3.5.*|0.3.6|>=0.3.6,<0.3.7.0a0',build=h828a276_2]
# nltk=3.4 -> numpy -> openblas[version='0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0']
# liblapacke -> libblas=3.8.0 -> openblas[version='0.3.5.*|0.3.6|>=0.3.6,<0.3.7.0a0',build=h828a276_2]
# libcblas -> libblas=3.8.0 -> openblas[version='0.3.5.*|0.3.6|>=0.3.6,<0.3.7.0a0',build=h828a276_2]
# py-opencv -> numpy[version='>=1.14.6,<2.0a0'] -> openblas[version='0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0']
# libblas -> openblas[version='0.3.5.*|0.3.6|>=0.3.6,<0.3.7.0a0',build=h828a276_2]
# matplotlib-base -> numpy[version='>=1.15.4,<2.0a0'] -> openblas[version='0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0']
# liblapack -> libblas=3.8.0 -> openblas[version='0.3.5.*|0.3.6|>=0.3.6,<0.3.7.0a0',build=h828a276_2]
# atari_py=0.2 -> numpy -> openblas[version='0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0']
# gym=0.18 -> numpy -> openblas[version='0.2.20|0.2.20.*|>=0.2.20,<0.2.21.0a0|>=0.3.3,<0.3.4.0a0']
#
# Package pip conflicts for:
# pysocks -> python[version='>=3.7,<3.8.0a0'] -> pip
# parso -> python[version='>=3.6'] -> pip
# pyopenssl -> python[version='>=2.7'] -> pip
# typing_extensions -> python[version='>=3.5'] -> pip
# regex -> python[version='>=3.9,<3.10.0a0'] -> pip
# prompt-toolkit -> python[version='>=3.6'] -> pip
# cycler -> python[version='>=3.6'] -> pip
# pickleshare -> python[version='>=3'] -> pip
# dataclasses -> python[version='>=3.7'] -> pip
# cloudpickle -> python[version='>=3.6'] -> pip
# ipython_genutils -> python -> pip
# nbclient -> python[version='>=3.6'] -> pip
# jupyterlab_widgets -> python[version='>=3.6'] -> pip
# idna -> python -> pip
# brotlipy -> python[version='>=3.7,<3.8.0a0'] -> pip
# wheel -> python[version='!=3.0,!=3.1,!=3.2,!=3.3,!=3.4'] -> pip
# pygments -> python[version='>=3.5'] -> pip
# certifi -> python[version='>=3.10,<3.11.0a0'] -> pip
# jupyter_core -> python[version='>=3.7,<3.8.0a0'] -> pip
# pyqtchart -> python[version='>=3.9,<3.10.0a0'] -> pip
# jupyterlab -> python[version='>=3.6'] -> pip
# tqdm=4.56 -> python[version='>=2.7'] -> pip
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> pip
# nbconvert -> python[version='>=3.9,<3.10.0a0'] -> pip
# cffi -> python[version='>=3.7,<3.8.0a0'] -> pip
# pyopengl=3.1 -> python -> pip
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> pip
# chardet -> python[version='>=3.9,<3.10.0a0'] -> pip
# pyglet=1.5 -> python[version='>=3.7,<3.8.0a0'] -> pip
# jedi -> python[version='>=3.9,<3.10.0a0'] -> pip
# numexpr=2.7 -> python[version='>=3.7,<3.8.0a0'] -> pip
# argon2-cffi -> python[version='>=3.8,<3.9.0a0'] -> pip
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> pip
# py-opencv -> python[version='>=3.8,<3.9.0a0'] -> pip
# pyqt-impl -> python[version='>=3.9,<3.10.0a0'] -> pip
# ipython=7.20 -> python[version='>=3.9,<3.10.0a0'] -> pip
# backcall -> python -> pip
# pytz -> python[version='>=3'] -> pip
# jinja2 -> python[version='>=3.6'] -> pip
# scipy=1.6 -> python[version='>=3.7,<3.8.0a0'] -> pip
# nltk=3.4 -> python -> pip
# markupsafe -> python[version='>=3.7,<3.8.0a0'] -> pip
# py-xgboost=0.90 -> python[version='>=3.7,<3.8.0a0'] -> pip
# nbformat -> python[version='>=3.5'] -> pip
# jupyter_console -> python[version='>=3.6'] -> pip
# babel -> python -> pip
# win_inet_pton -> python[version='>=3.8,<3.9.0a0'] -> pip
# async_generator -> python[version='>2.7'] -> pip
# matplotlib-base -> python[version='>=3.8,<3.9.0a0'] -> pip
# scikit-learn=0.24 -> python[version='>=3.7,<3.8.0a0'] -> pip
# prompt_toolkit -> python[version='>=3.6'] -> pip
# backports -> python -> pip
# click -> python[version='>=3.7,<3.8.0a0'] -> pip
# gitdb -> python[version='>=3.4'] -> pip
# jupyter_server -> python[version='>=3.6'] -> pip
# jupyterlab_pygments -> python -> pip
# pyzmq -> python[version='>=3.7,<3.8.0a0'] -> pip
# atari_py=0.2 -> python[version='>=3.10,<3.11.0a0'] -> pip
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> pip
# python-dateutil -> python[version='>=3.6'] -> pip
# decorator -> python[version='>=3.5'] -> pip
# pycparser -> python[version='=2.7|>=3.4'] -> pip
# python-graphviz -> python[version='>=3'] -> pip
# entrypoints -> python[version='>=3.6'] -> pip
# six -> python -> pip
# gym=0.18 -> python[version='>=3.9,<3.10.0a0'] -> pip
# ipywidgets=7.6 -> python[version='>=3.3'] -> pip
# jupyter=1.0 -> python[version='>=3.9,<3.10.0a0'] -> pip
# tokenizers -> python[version='>=3.8,<3.9.0a0'] -> pip
# pillow=8.1 -> python[version='>=3.9,<3.10.0a0'] -> pip
# tornado -> python[version='>=3.7,<3.8.0a0'] -> pip
# jsonschema -> python[version='>=3.7'] -> pip
# threadpoolctl -> python[version='>=3.6'] -> pip
# importlib-metadata -> python[version='>=3.10,<3.11.0a0'] -> pip
# sniffio -> python[version='>=3.9,<3.10.0a0'] -> pip
# filelock -> python[version='>=3.6'] -> pip
# pywinpty -> python[version='>=3.7,<3.8.0a0'] -> pip
# widgetsnbextension=3.5 -> python[version='>=3.9,<3.10.0a0'] -> pip
# jupyter_client -> python[version='>=3.6.1'] -> pip
# testpath -> python[version='>=3.5'] -> pip
# defusedxml -> python[version='>=3.6'] -> pip
# notebook -> python[version='>=3.7'] -> pip
# nbdime=2.1 -> python[version='>=3.6'] -> pip
# attrs -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*'] -> pip
# joblib=0.14 -> python -> pip
# nest-asyncio -> python[version='>=3.5'] -> pip
# packaging -> python[version='>=3.6'] -> pip
# webencodings -> python -> pip
# future -> python[version='>=3.7,<3.8.0a0'] -> pip
# setuptools -> python[version='>=3.9,<3.10.0a0'] -> pip
# python_abi -> python=3.10 -> pip
# terminado -> python[version='>=3.8,<3.9.0a0'] -> pip
# json5 -> python -> pip
# anyio -> python[version='>=3.7,<3.8.0a0'] -> pip
# olefile -> python -> pip
# requests-unixsocket -> python -> pip
# qtpy -> python[version='>=3.6'] -> pip
# transformers=4.3 -> python[version='>=3.6'] -> pip
# smmap -> python[version='>=3.5'] -> pip
# pyqt5-sip -> python[version='>=3.8,<3.9.0a0'] -> pip
# pyparsing -> python[version='>=3.6'] -> pip
# zipp -> python[version='>=3.6'] -> pip
# bleach -> python[version='>=3.6'] -> pip
# pyqtwebengine -> python[version='>=3.9,<3.10.0a0'] -> pip
# numpy=1.19 -> python[version='>=3.9,<3.10.0a0'] -> pip
# matplotlib=3.3 -> python[version='>=3.7,<3.8.0a0'] -> pip
# jupyterlab_server -> python[version='>=3.6'] -> pip
# python=3.7 -> pip
# websocket-client -> python[version='>=3.9,<3.10.0a0'] -> pip
# backports.functools_lru_cache -> python[version='>=3.6'] -> pip
# pandas=1.2 -> python[version='>=3.7,<3.8.0a0'] -> pip
# ftfy=5.8 -> python[version='>=3.6,<3.9'] -> pip
# gitpython -> python[version='>=3.7'] -> pip
# requests=2.25 -> python -> pip
# send2trash -> python[version='>=3.6'] -> pip
# sacremoses -> python[version='>=3.6'] -> pip
# kiwisolver -> python[version='>=3.10,<3.11.0a0'] -> pip
# box2d-py=2.3 -> python[version='>=3.8,<3.9.0a0'] -> pip
# qtconsole -> python[version='>=3.6'] -> pip
# wcwidth -> python -> pip
# cryptography -> python[version='>=3.9,<3.10.0a0'] -> pip
# prometheus_client -> python[version='>=3.6'] -> pip
# urllib3 -> python[version='<4.0'] -> pip
# pywin32 -> python[version='>=3.8,<3.9.0a0'] -> pip
# colorama -> python -> pip
# traitlets -> python[version='>=3.7'] -> pip
# mistune -> python[version='>=3.9,<3.10.0a0'] -> pip
#
# Package vc conflicts for:
# pywinpty -> vc[version='14.*|>=14.2,<15|9.*']
# freetype -> vc[version='10.*|10|14|14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0|9']
# libtiff -> vc[version='10.*|10|14|14.*|>=14.1,<15.0a0|9.*|9']
# python=3.7 -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0']
# kiwisolver -> python[version='>=2.7,<2.8.0a0'] -> vc[version='>=9,<10.0a0']
# jasper -> freeglut[version='>=3.0.0,<4.0a0'] -> vc[version='10.*|14.*|9.*|>=14,<15.0a0']
# websocket-client -> python[version='>=3.9,<3.10.0a0'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# nbclient -> python[version='>=3.6'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0']
# pyqt-impl -> vc[version='>=14.1,<15.0a0']
# box2d-py=2.3 -> vc[version='>=14,<15.0a0|>=14.1,<15.0a0']
# libwebp-base -> vc[version='>=14,<15.0a0|>=14.1,<15.0a0']
# json5 -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# defusedxml -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# typing_extensions -> python[version='>=3.5'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# requests=2.25 -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# libwebp -> vc[version='10.*|14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# anyio -> python[version='>=3.7,<3.8.0a0'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0']
# requests-unixsocket -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# graphviz -> cairo[version='>=1.16.0,<1.17.0a0'] -> vc[version='>=14,<15.0a0']
# sniffio -> python[version='>=3.9,<3.10.0a0'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0']
# pango -> vc[version='>=14.1,<15.0a0']
# atari_py=0.2 -> vc[version='>=14.1,<15.0a0']
# libsodium -> vc[version='14.*|14|9|>=14,<15.0a0|>=14.1,<15.0a0|>=9,<10.0a0|9.*']
# pyqt-impl -> python[version='>=3.6,<3.7.0a0'] -> vc[version='14.*|>=14,<15.0a0']
# openjpeg -> vc[version='10.*|10|14|14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0|9']
# future -> pypy3.7[version='>=7.3.7'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# lcms2 -> jpeg[version='>=9c,<10a'] -> vc[version='14.*|9.*']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# libdeflate -> vc[version='>=14.1,<15.0a0']
# xorg-libxext -> vc[version='14|9']
# getopt-win32 -> vc[version='>=14.1,<15.0a0']
# libxcb -> vc[version='14|9']
# scipy=1.6 -> vc[version='>=14.1,<15.0a0']
# pywin32 -> python=2.7 -> vc[version='>=9,<10.0a0']
# python_abi -> python=3.10 -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# pillow=8.1 -> vc[version='>=14.1,<15.0a0']
# pyopengl=3.1 -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# pycparser -> python[version='=2.7|>=3.4'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# numexpr=2.7 -> vc[version='9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# backcall -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# pytz -> python[version='>=3'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# nltk=3.4 -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# jupyterlab_server -> python[version='>=3.6'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0']
# backports.functools_lru_cache -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# scikit-learn=0.24 -> python[version='>=3.7,<3.8.0a0'] -> vc[version='14.*|>=14,<15.0a0|9.*']
# libxcb -> pthread-stubs -> vc[version='14.*|9.*']
# pandas=1.2 -> numpy[version='>=1.17.5,<2.0a0'] -> vc[version='14.*|>=14,<15.0a0|9.*']
# pyqtchart -> vc[version='>=14.1,<15.0a0']
# tornado -> python[version='>=2.7,<2.8.0a0'] -> vc[version='10.*|>=9,<10.0a0']
# ffmpeg -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# jpeg -> vc[version='14.*|>=14.1,<15.0a0|9.*|>=14,<15.0a0']
# async_generator -> python[version='>2.7'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# pywinpty -> python[version='>=3.7,<3.8.0a0'] -> vc[version='>=14,<15.0a0|>=14.1,<15.0a0|>=9,<10.0a0|>=14.2,<15.0a0']
# sqlite -> zlib[version='>=1.2.11,<1.3.0a0'] -> vc[version='>=9,<10.0a0']
# libxgboost -> vc[version='>=14.1,<15.0a0']
# backports -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# filelock -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# babel -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# xorg-libx11 -> vc[version='14|9']
# ipykernel -> debugpy[version='>=1,<2.0'] -> vc[version='10.*|14.*|>=14,<15.0a0|>=14.1,<15.0a0|9.*|>=9,<10.0a0']
# widgetsnbextension=3.5 -> python[version='>=3.9,<3.10.0a0'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# cloudpickle -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# markupsafe -> python[version='>=2.7,<2.8.0a0'] -> vc[version='10.*|>=9,<10.0a0']
# jupyterlab_pygments -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# gts -> vc[version='>=14.1,<15.0a0']
# graphviz -> vc[version='14.*|9.*|>=14.1,<15.0a0']
# gts -> glib[version='>=2.58.3,<3.0a0'] -> vc[version='14.*|>=14,<15.0a0']
# graphite2 -> vc=14
# libopencv -> libpng[version='>=1.6.37,<1.7.0a0'] -> vc[version='10.*|9.*|>=9,<10.0a0|9|14']
# cryptography -> python[version='>=2.7,<2.8.0a0'] -> vc[version='10.*|>=9,<10.0a0']
# decorator -> python[version='>=3.5'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# send2trash -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# pyqt5-sip -> vc[version='>=14.1,<15.0a0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0'] -> vc[version='>=14,<15.0a0|>=9,<10.0a0']
# pygments -> python[version='>=3.5'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# packaging -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# lerc -> vc[version='>=14.1,<15.0a0']
# fontconfig -> vc[version='14.*|>=14,<15.0a0|>=14.1,<15.0a0']
# regex -> vc[version='14.*|>=14,<15.0a0|>=14.1,<15.0a0|9.*']
# xorg-libxt -> vc[version='14|9']
# openjpeg -> zlib[version='>=1.2.11,<1.3.0a0'] -> vc[version='>=9,<10.0a0']
# lz4-c -> vc[version='14.*|14|>=14,<15.0a0|>=14.1,<15.0a0|9.*']
# jinja2 -> markupsafe[version='>=2.0'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|9.*|>=9,<10.0a0']
# certifi -> python[version='>=3.10,<3.11.0a0'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# terminado -> python[version='>=3.8,<3.9.0a0'] -> vc[version='14.*|>=14,<15.0a0|>=14.1,<15.0a0|>=14.2,<15|9.*|>=9,<10.0a0']
# libpng -> vc[version='10.*|10|14|14.*|>=14.1,<15.0a0|9.*|9']
# fribidi -> vc[version='>=14.1,<15.0a0']
# libtiff -> zlib[version='>=1.2.11,<1.3.0a0'] -> vc[version='>=14,<15.0a0|>=9,<10.0a0']
# threadpoolctl -> python[version='>=3.6'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0']
# mkl -> tbb=2021 -> vc[version='>=14.1,<15.0a0']
# cycler -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# bleach -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# pip -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# qt -> vc[version='14.*|>=14.1,<15.0a0|9.*']
# tokenizers -> vc[version='>=14.1,<15.0a0']
# ipython_genutils -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# libblas -> libopenblas==0.3.18=pthreads_hc469a61_0 -> vc[version='>=14,<15.0a0|>=14.1,<15.0a0']
# pango -> cairo[version='>=1.16.0,<1.17.0a0'] -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.2,<15']
# nbconvert -> mistune[version='>=0.8.1,<2'] -> vc[version='10.*|14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0']
# testpath -> python[version='>=3.5'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# pyopenssl -> cryptography[version='>=3.3'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# atari_py=0.2 -> numpy -> vc[version='14.*|9.*|>=14,<15.0a0|>=9,<10.0a0']
# freeglut -> vc[version='10.*|14.*|>=14.1,<15.0a0|9.*']
# attrs -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# brotlipy -> python[version='>=2.7,<2.8.0a0'] -> vc[version='>=9,<10.0a0']
# wheel -> python[version='!=3.0,!=3.1,!=3.2,!=3.3,!=3.4'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# pcre -> vc[version='10|14|14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0|9']
# lcms2 -> vc[version='>=14.1,<15.0a0']
# markupsafe -> vc[version='14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0']
# gettext -> vc[version='14.*|>=14,<15.0a0|>=14.1,<15.0a0']
# pyrsistent -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# cffi -> vc[version='14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0']
# webencodings -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# zlib -> vc[version='10.*|14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0|>=9,<10.0a0']
# tbb -> vc[version='10.*|14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# tqdm=4.56 -> python[version='>=2.7'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# py-xgboost=0.90 -> numpy -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0|>=9,<10.0a0']
# pillow=8.1 -> tk[version='>=8.6.10,<8.7.0a0'] -> vc[version='10.*|10|14|14.*|9.*|>=14,<15.0a0|>=9,<10.0a0|9']
# pyrsistent -> python[version='>=2.7,<2.8.0a0'] -> vc[version='>=9,<10.0a0']
# idna -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# olefile -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# sacremoses -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|9.*|>=9,<10.0a0']
# cryptography -> vc[version='14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0']
# click -> python[version='>=3.7,<3.8.0a0'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# qtconsole -> pyqt -> vc[version='10.*|14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0|>=9,<10.0a0']
# six -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# tokenizers -> python[version='>=3.6,<3.7.0a0'] -> vc[version='14.*|>=14,<15.0a0']
# scipy=1.6 -> numpy[version='>=1.17.5,<2.0a0'] -> vc[version='14.*|>=14,<15.0a0|9.*']
# setuptools -> python[version='>=3.9,<3.10.0a0'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# libiconv -> vc[version='10.*|10|14|14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0|9']
# python-dateutil -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# cffi -> python[version='>=2.7,<2.8.0a0'] -> vc[version='10.*|>=9,<10.0a0']
# xorg-libxau -> vc[version='14|9']
# cairo -> zlib[version='>=1.2.11,<1.3.0a0'] -> vc[version='10.*|>=9,<10.0a0']
# prompt-toolkit -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# ftfy=5.8 -> python[version='>=3.6,<3.9'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0']
# notebook -> argon2-cffi -> vc[version='10.*|14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0|>=9,<10.0a0']
# ipython=7.20 -> python[version='>=3.9,<3.10.0a0'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0']
# regex -> python[version='>=2.7,<2.8.0a0'] -> vc[version='10.*|>=9,<10.0a0']
# python-graphviz -> graphviz[version='>=2.46.1'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|9.*|>=9,<10.0a0']
# pyzmq -> vc[version='14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0']
# libxml2 -> zlib[version='>=1.2.11,<1.3.0a0'] -> vc[version='>=9,<10.0a0']
# qtpy -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# dataclasses -> python[version='>=3.7'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0']
# colorama -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# jbig -> vc[version='>=14.1,<15.0a0']
# cairo -> vc[version='10|14|14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0|9']
# nest-asyncio -> python[version='>=3.5'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0']
# pyzmq -> libsodium[version='>=1.0.17,<1.0.18.0a0'] -> vc[version='10.*|14|9|>=9,<10.0a0']
# traitlets -> python[version='>=3.7'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# nbformat -> python[version='>=3.5'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# pyqt5-sip -> python[version='>=3.7,<3.8.0a0'] -> vc[version='14.*|>=14,<15.0a0']
# jupyter_console -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# jupyter=1.0 -> python[version='>=3.9,<3.10.0a0'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# expat -> vc[version='10.*|14.*|14|9|>=14,<15.0a0|>=14.1,<15.0a0|>=9,<10.0a0|9.*']
# gettext -> libffi[version='>=3.2.1,<3.3.0a0'] -> vc=9
# scikit-learn=0.24 -> vc[version='>=14.1,<15.0a0']
# zipp -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# prompt_toolkit -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# gitpython -> python[version='>=3.7'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# xorg-libsm -> vc[version='14|9']
# jupyterlab -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|9.*|>=9,<10.0a0|>=14.2,<15.0a0']
# numexpr=2.7 -> python[version='>=3.7,<3.8.0a0'] -> vc[version='14.*|>=9,<10.0a0']
# libffi -> vc[version='14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0']
# tornado -> vc[version='14.*|>=14,<15.0a0|>=14.1,<15.0a0|9.*']
# gitdb -> python[version='>=3.4'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# pyqt -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# matplotlib-base -> vc[version='14.*|>=14,<15.0a0|>=14.1,<15.0a0|9.*']
# xorg-libice -> vc[version='14|9']
# argon2-cffi -> cffi[version='>=1.0.0'] -> vc[version='14.*|>=9,<10.0a0']
# gym=0.18 -> numpy -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0'] -> vc[version='>=9,<10.0a0']
# argon2-cffi -> vc[version='9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# box2d-py=2.3 -> python[version='>=3.7,<3.8.0a0'] -> vc=14
# mistune -> python[version='>=2.7,<2.8.0a0'] -> vc[version='10.*|>=9,<10.0a0']
# prometheus_client -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# pyqtwebengine -> vc[version='>=14.1,<15.0a0']
# matplotlib=3.3 -> matplotlib-base[version='>=3.3.4,<3.3.5.0a0'] -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# jupyter_client -> python[version='>=3.6.1'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|9.*|>=9,<10.0a0|>=14.2,<15.0a0']
# transformers=4.3 -> numpy -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# kiwisolver -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# openssl -> vc[version='10.*|14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0']
# pywin32 -> vc[version='14.*|>=14,<15.0a0|>=14.1,<15.0a0|>=14.2,<15.0a0|9.*']
# qt -> zlib[version='>=1.2.11,<1.3.0a0'] -> vc[version='10.*|14|9|>=14,<15.0a0|>=9,<10.0a0']
# libprotobuf -> vc[version='14.*|>=14,<15.0a0|>=14.1,<15.0a0|9.*']
# fontconfig -> libxml2[version='>=2.9.10,<2.10.0a0'] -> vc[version='14|9|9.*']
# wcwidth -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# winpty -> vc=14
# jupyter_server -> argon2-cffi -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0|>=14.2,<15.0a0|>=9,<10.0a0']
# harfbuzz -> cairo[version='>=1.16.0,<1.17.0a0'] -> vc[version='14|9|9.*']
# pysocks -> pypy3.7[version='>=7.3.7'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# mistune -> vc[version='14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0']
# pixman -> vc[version='10|14|14.*|9.*|>=14.1,<15.0a0|9']
# pyqt -> python[version='>=2.7,<2.8.0a0'] -> vc[version='10.*|>=9,<10.0a0']
# libgd -> vc[version='>=14.1,<15.0a0']
# xz -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0|>=9,<10.0a0']
# pandas=1.2 -> vc[version='>=14.1,<15.0a0']
# harfbuzz -> vc[version='14.*|>=14,<15.0a0|>=14.1,<15.0a0|>=14.2,<15']
# urllib3 -> brotlipy[version='>=0.6.0'] -> vc[version='10.*|14.*|>=14,<15.0a0|>=14.1,<15.0a0|9.*|>=9,<10.0a0']
# matplotlib-base -> zlib[version='>=1.2.11,<1.3.0a0'] -> vc[version='>=9,<10.0a0']
# chardet -> python[version='>=3.9,<3.10.0a0'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# xorg-libxdmcp -> vc[version='14|9']
# pyqtchart -> python[version='>=3.6,<3.7.0a0'] -> vc[version='14.*|>=14,<15.0a0']
# jupyter_core -> python[version='>=3.7,<3.8.0a0'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=14.2,<15.0a0|9.*|>=9,<10.0a0']
# libclang -> zlib[version='>=1.2.11,<1.3.0a0'] -> vc[version='14.*|9.*|>=9,<10.0a0']
# libxml2 -> vc[version='10.*|10|14|14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0|9']
# libglib -> vc[version='>=14.1,<15.0a0']
# nbdime=2.1 -> python[version='>=3.6'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0|9.*']
# libglib -> gettext[version='>=0.19.8.1,<1.0a0'] -> vc[version='14.*|>=14,<15.0a0|>=9,<10.0a0|9.*']
# brotlipy -> vc[version='14.*|>=14,<15.0a0|>=14.1,<15.0a0|9.*']
# pthread-stubs -> vc[version='14.*|9.*']
# numpy=1.19 -> vc[version='>=14.1,<15.0a0']
# zstd -> vc[version='14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0|>=9,<10.0a0']
# entrypoints -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# libopencv -> vc[version='14.*|>=14,<15.0a0|>=14.1,<15.0a0']
# pickleshare -> python[version='>=3'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# python=3.7 -> sqlite[version='>=3.30.1,<4.0a0'] -> vc=9
# sqlite -> vc[version='10.*|10|14|14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0|9']
# jasper -> vc[version='>=14.1,<15.0a0']
# tk -> vc[version='10.*|10|14|14.*|9.*|>=14.1,<15.0a0|>=14,<15.0a0|9']
# ipywidgets=7.6 -> python[version='>=3.3'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# win_inet_pton -> python[version='>=3.8,<3.9.0a0'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# libprotobuf -> zlib[version='>=1.2.11,<1.3.0a0'] -> vc[version='>=9,<10.0a0']
# zstd -> lz4-c[version='>=1.8.1.2,<1.8.2.0a0'] -> vc==14
# parso -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# jsonschema -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0'] -> vc[version='10.*|14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0|>=9,<10.0a0']
# pyglet=1.5 -> ffmpeg -> vc[version='10.*|10|14|14.*|9.*|>=14,<15.0a0|>=14.1,<15.0a0|9']
# jupyterlab_widgets -> python[version='>=3.6'] -> vc[version='14.*|>=14.1,<15.0a0|>=14,<15.0a0']
# libgd -> fontconfig[version='>=2.13.1,<3.0a0'] -> vc[version='10.*|14.*|>=14,<15.0a0|9.*|9|14|>=9,<10.0a0']
# numpy=1.19 -> python[version='>=3.7,<3.8.0a0'] -> vc[version='14.*|>=14,<15.0a0|9.*']
# smmap -> python[version='>=3.5'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# libclang -> vc[version='>=14,<15.0a0|>=14.1,<15.0a0']
# pyqtwebengine -> python[version='>=3.6,<3.7.0a0'] -> vc[version='14.*|>=14,<15.0a0']
# xorg-libxpm -> vc[version='14|9']
# pyparsing -> python[version='>=3.6'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# joblib=0.14 -> python -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
# icu -> vc[version='10.*|14.*|14|9|>=14,<15.0a0|>=14.1,<15.0a0|9.*']
# opencv=4.5 -> libopencv==4.5.3=py38hb110498_5 -> vc[version='>=14.1,<15.0a0']
# py-opencv -> python[version='>=3.7,<3.8.0a0'] -> vc[version='9.*|>=14,<15.0a0']
# py-opencv -> vc[version='14.*|>=14.1,<15.0a0']
# zeromq -> vc[version='14.*|14|9|9.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0']
# importlib-metadata -> python[version='>=3.10,<3.11.0a0'] -> vc[version='10.*|14.*|>=14.1,<15.0a0|>=14,<15.0a0|>=9,<10.0a0|9.*']
#
# Package libffi conflicts for:
# pywinpty -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# prometheus_client -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# pango -> libglib[version='>=2.68.4,<3.0a0'] -> libffi[version='>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# numpy=1.19 -> pypy3.7[version='>=7.3.5'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0']
# send2trash -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# regex -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# python_abi -> python=3.10 -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# brotlipy -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# matplotlib-base -> pypy3.7[version='>=7.3.5'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0']
# idna -> python -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# olefile -> python -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# chardet -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# pygments -> python[version='>=3.5'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# pysocks -> pypy3.7[version='>=7.3.7'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# jsonschema -> python[version='>=3.7'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# widgetsnbextension=3.5 -> python -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# filelock -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# mistune -> pypy3.7[version='>=7.3.7'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# certifi -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# backports.functools_lru_cache -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# gitpython -> python[version='>=3.7'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# jupyter_console -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# anyio -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# markupsafe -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# jupyterlab_pygments -> python -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# harfbuzz -> libglib[version='>=2.70.0,<3.0a0'] -> libffi[version='>=3.2.1,<3.3.0a0|>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0|>=3.2.1,<3.3a0']
# joblib=0.14 -> python -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# nbdime=2.1 -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# pyrsistent -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# qtpy -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# argon2-cffi -> pypy3.7[version='>=7.3.7'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# packaging -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# pyopengl=3.1 -> python -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# threadpoolctl -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# cycler -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# ipython_genutils -> python -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# testpath -> python[version='>=3.5'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# nbclient -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# async_generator -> python[version='>2.7'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# zipp -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# entrypoints -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# pyparsing -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# websocket-client -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# nest-asyncio -> python[version='>=3.5'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# attrs -> python[version='>=2.7,!=3.0.*,!=3.1.*,!=3.2.*,!=3.3.*,!=3.4.*'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# transformers=4.3 -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# python-dateutil -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# json5 -> python -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# requests-unixsocket -> python -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# requests=2.25 -> python -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# graphviz -> libglib[version='>=2.70.0,<3.0a0'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4.2,<3.5.0a0']
# jupyter_server -> python[version='>=3.6'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# setuptools -> pypy3.7[version='>=7.3.7'] -> libffi[version='>=3.3,<3.4.0a0|>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# pywin32 -> python[version='>=3.10,<3.11.0a0'] -> libffi[version='>=3.4,<4.0a0|>=3.4.2,<3.5.0a0']
# ...
# matplotlib=3.3 -> matplotlib-base[version='>=3.3.0,<3.3.1.0a0|>=3.3.1,<3.3.2.0a0|>=3.3.2,<3.3.3.0a0|>=3.3.3,<3.3.4.0a0|>=3.3.4,<3.3.5.0a0']
#
# Package jupyter_server conflicts for:
# jupyterlab -> jupyter_server[version='>=1.1.0,<2.0.0|>=1.2,<2|>=1.4,<2']
# jupyterlab -> nbclassic[version='>=0.2,<1'] -> jupyter_server[version='>=1.0.1,<2.0.0|>=1.5.0,<2.0.0|>=1.8.0,<2.0.0']
# jupyterlab_server -> jupyter_server[version='>=1.1.0,<2.0.0|>=1.4,<2']
#
# Package xorg-libxau conflicts for:
# libxcb -> xorg-libxau
# xorg-libx11 -> libxcb=1 -> xorg-libxau
#
# Package libxml2 conflicts for:
# cairo -> fontconfig[version='>=2.13.1,<3.0a0'] -> libxml2[version='>=2.9.10,<2.10.0a0|>=2.9.9,<2.10.0a0|>=2.9.8,<2.10.0a0']
# pango -> fontconfig[version='>=2.13.1,<3.0a0'] -> libxml2[version='>=2.9.10,<2.10.0a0|>=2.9.9,<2.10.0a0|>=2.9.8,<2.10.0a0']
# fontconfig -> libxml2[version='>=2.9.10,<2.10.0a0|>=2.9.9,<2.10.0a0|>=2.9.8,<2.10.0a0']
# libgd -> fontconfig[version='>=2.13.1,<3.0a0'] -> libxml2[version='>=2.9.10,<2.10.0a0|>=2.9.9,<2.10.0a0|>=2.9.8,<2.10.0a0']
#
# Package click conflicts for:
# sacremoses -> click
# transformers=4.3 -> sacremoses -> click
# attrs -> hypothesis -> click[version='>=7.0']
#
# Package joblib conflicts for:
# nltk=3.4 -> scikit-learn -> joblib[version='>=0.11']
# transformers=4.3 -> sacremoses -> joblib
# scikit-learn=0.24 -> joblib[version='>=0.11']
# sacremoses -> joblib
# py-xgboost=0.90 -> scikit-learn -> joblib[version='>=0.11']
#
# Package libdeflate conflicts for:
# pillow=8.1 -> libtiff[version='>=4.2.0,<5.0a0'] -> libdeflate[version='>=1.7,<1.8.0a0|>=1.8,<1.9.0a0']
# openjpeg -> libtiff[version='>=4.2.0,<5.0a0'] -> libdeflate[version='>=1.7,<1.8.0a0|>=1.8,<1.9.0a0']
# libgd -> libtiff[version='>=4.3.0,<5.0a0'] -> libdeflate[version='>=1.7,<1.8.0a0|>=1.8,<1.9.0a0']
# libopencv -> libtiff[version='>=4.3.0,<5.0a0'] -> libdeflate[version='>=1.7,<1.8.0a0|>=1.8,<1.9.0a0']
# lcms2 -> libtiff[version='>=4.2.0,<5.0a0'] -> libdeflate[version='>=1.7,<1.8.0a0|>=1.8,<1.9.0a0']
# libtiff -> libdeflate[version='>=1.7,<1.8.0a0|>=1.8,<1.9.0a0']
#
# Package backports.shutil_which conflicts for:
# pywinpty -> backports.shutil_which
# terminado -> pywinpty[version='>=0.5,<1'] -> backports.shutil_which
#
# Package python-pathlib2 conflicts for:
# pickleshare -> python-pathlib2
# ipython=7.20 -> pickleshare -> python-pathlib2
#
# Package pyrsistent conflicts for:
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0']
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0']
# jsonschema -> pyrsistent[version='!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0|>=0.14.0']
#
# Package zope.interface conflicts for:
# attrs -> zope.interface
# prometheus_client -> twisted -> zope.interface[version='>=4.0.2|>=4.4.2']
#
# Package cairo conflicts for:
# pango -> cairo[version='>=1.16.0,<1.17.0a0']
# python-graphviz -> graphviz[version='>=2.46.1'] -> cairo[version='>=1.16.0,<1.17.0a0']
# graphviz -> cairo[version='>=1.16.0,<1.17.0a0']
# harfbuzz -> cairo[version='>=1.16.0,<1.17.0a0']
#
# Package prompt-toolkit conflicts for:
# jupyterlab -> ipython -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0|>=2.0.0,!=3.0.0,!=3.0.1,<3.1.0']
# ipywidgets=7.6 -> ipython[version='>=4.0.0'] -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0|>=2.0.0,!=3.0.0,!=3.0.1,<3.1.0']
# ipython=7.20 -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0|>=2.0.0,!=3.0.0,!=3.0.1,<3.1.0']
# prompt_toolkit -> prompt-toolkit[version='>=3.0.10,<3.0.11.0a0|>=3.0.11,<3.0.12.0a0|>=3.0.13,<3.0.14.0a0|>=3.0.14,<3.0.15.0a0|>=3.0.16,<3.0.17.0a0|>=3.0.17,<3.0.18.0a0|>=3.0.18,<3.0.19.0a0|>=3.0.19,<3.0.20.0a0|>=3.0.20,<3.0.21.0a0|>=3.0.21,<3.0.22.0a0|>=3.0.22,<3.0.23.0a0|>=3.0.9,<3.0.10.0a0|>=3.0.8,<3.0.9.0a0|>=3.0.7,<3.0.8.0a0|>=3.0.6,<3.0.7.0a0|>=3.0.5,<3.0.6.0a0|>=3.0.4,<3.0.5.0a0']
# ipykernel -> ipython[version='>=7.23.1,<8.0'] -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0|>=2.0.0,!=3.0.0,!=3.0.1,<3.1.0']
# jupyter_console -> ipython -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0|>=2.0.0,!=3.0.0,!=3.0.1,<3.1.0|>=3.0.22,<3.0.23.0a0|>=3.0.21,<3.0.22.0a0|>=3.0.20,<3.0.21.0a0|>=3.0.19,<3.0.20.0a0|>=3.0.18,<3.0.19.0a0|>=3.0.17,<3.0.18.0a0|>=3.0.16,<3.0.17.0a0|>=3.0.14,<3.0.15.0a0|>=3.0.13,<3.0.14.0a0|>=3.0.11,<3.0.12.0a0|>=3.0.10,<3.0.11.0a0|>=3.0.9,<3.0.10.0a0|>=3.0.8,<3.0.9.0a0|>=3.0.7,<3.0.8.0a0|>=3.0.6,<3.0.7.0a0|>=3.0.5,<3.0.6.0a0|>=3.0.4,<3.0.5.0a0']
#
# Package fonts-conda-ecosystem conflicts for:
# harfbuzz -> cairo[version='>=1.16.0,<1.17.0a0'] -> fonts-conda-ecosystem
# cairo -> fonts-conda-ecosystem
# pango -> fonts-conda-ecosystem
# graphviz -> cairo[version='>=1.16.0,<1.17.0a0'] -> fonts-conda-ecosystem
# libgd -> fonts-conda-ecosystem
#
# Package requests-unixsocket conflicts for:
# jupyter_server -> requests-unixsocket
# jupyterlab_server -> jupyter_server[version='>=1.4,<2'] -> requests-unixsocket
# jupyterlab -> jupyter_server[version='>=1.4,<2'] -> requests-unixsocket
#
# Package babel conflicts for:
# jupyterlab_server -> babel
# jupyterlab -> jupyterlab_server[version='>=2.3,<3'] -> babel
#
# Package win_inet_pton conflicts for:
# pysocks -> win_inet_pton
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7'] -> win_inet_pton
#
# Package xorg-xextproto conflicts for:
# libgd -> xorg-libxpm -> xorg-xextproto
# xorg-libxpm -> xorg-xextproto
# xorg-libxext -> xorg-xextproto
#
# Package qt conflicts for:
# matplotlib=3.3 -> pyqt -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.12.9,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0|>=5.9.4,<5.10.0a0']
# libopencv -> qt[version='5.12.*|>=5.12.9,<5.13.0a0|>=5.12.1,<5.13.0a0']
# opencv=4.5 -> libopencv==4.5.3=py38hb110498_5 -> qt[version='5.12.*|>=5.12.9,<5.13.0a0|>=5.12.1,<5.13.0a0']
# qtconsole -> pyqt -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.12.9,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0|>=5.9.4,<5.10.0a0']
# py-opencv -> libopencv==4.5.3=py38hb110498_5 -> qt[version='5.12.*|>=5.12.9,<5.13.0a0|>=5.12.1,<5.13.0a0']
# pyqtchart -> qt[version='>=5.12.9,<5.13.0a0']
# pyqt -> qt[version='4.8.*|5.6.*|5.9.*|>=5.12.5,<5.13.0a0|>=5.12.9,<5.13.0a0|>=5.9.7,<5.10.0a0|>=5.6.2,<5.7.0a0|>=5.9.6,<5.10.0a0|>=5.9.4,<5.10.0a0']
# pyqtwebengine -> qt[version='>=5.12.9,<5.13.0a0']
# pyqt-impl -> qt[version='>=5.12.9,<5.13.0a0']
#
# Package pycparser conflicts for:
# argon2-cffi -> cffi[version='>=1.0.0'] -> pycparser[version='>=2.06']
# cryptography -> cffi[version='>=1.12'] -> pycparser[version='>=2.06']
# cffi -> pycparser[version='>=2.06']
# brotlipy -> cffi[version='>=1.0.0'] -> pycparser[version='>=2.06']
#
# Package widgetsnbextension conflicts for:
# jupyter=1.0 -> ipywidgets -> widgetsnbextension[version='>=1.2.2|>=1.2.3|>=1.2.6|>=1.2.6,<2|>=2.0.0|>=2.0.0,<3.0.0|>=3.0.0|>=3.0.0,<3.1.0|>=3.1.0,<3.2.0|>=3.2.0,<3.3.0|>=3.3.0,<3.4.0|>=3.4.0,<3.5.0|>=3.5.0,<3.6.0|>=3.2.0,<4.0.0|>=3.1.0,<4.0.0|>=3.0.0,<4.0.0|>=3.1.0,<4.0']
# ipywidgets=7.6 -> widgetsnbextension[version='>=3.5.0,<3.6.0']
#
# Package scikit-learn conflicts for:
# nltk=3.4 -> scikit-learn
# py-xgboost=0.90 -> scikit-learn
#
# Package lcms2 conflicts for:
# pillow=8.1 -> lcms2[version='>=2.12,<3.0a0']
# matplotlib-base -> pillow[version='>=6.2.0'] -> lcms2[version='>=2.12,<3.0a0']
#
# Package typing-extensions conflicts for:
# gitpython -> typing-extensions[version='>=3.7.4.0']
# nbdime=2.1 -> gitpython[version='!=2.1.4,!=2.1.5,!=2.1.6'] -> typing-extensions[version='>=3.7.4.0']
# prometheus_client -> twisted -> typing-extensions[version='>=3.6.5']
#
# Package font-ttf-ubuntu conflicts for:
# fonts-conda-forge -> font-ttf-ubuntu
# fonts-conda-ecosystem -> fonts-conda-forge -> font-ttf-ubuntu
#
# Package freeglut conflicts for:
# jasper -> freeglut[version='>=3.0.0,<4.0a0|>=3.2.1,<4.0a0']
# libopencv -> jasper[version='>=2.0.14,<3.0a0'] -> freeglut[version='>=3.0.0,<4.0a0|>=3.2.1,<4.0a0']
#
# Package font-ttf-inconsolata conflicts for:
# fonts-conda-ecosystem -> fonts-conda-forge -> font-ttf-inconsolata
# fonts-conda-forge -> font-ttf-inconsolata
#
# Package pywinpty conflicts for:
# terminado -> pywinpty[version='>=0.5|>=0.5,<1|>=1.1']
# notebook -> terminado[version='>=0.8.3'] -> pywinpty[version='>=0.5|>=0.5,<1|>=1.1']
# jupyter_server -> terminado[version='>=0.8.3'] -> pywinpty[version='>=0.5|>=0.5,<1|>=1.1']
#
# Package libgd conflicts for:
# python-graphviz -> graphviz[version='>=2.46.1'] -> libgd[version='>=2.3.0,<2.4.0a0|>=2.3.2,<2.4.0a0|>=2.3.3,<2.4.0a0']
# graphviz -> libgd[version='>=2.3.0,<2.4.0a0|>=2.3.2,<2.4.0a0|>=2.3.3,<2.4.0a0']
#
# Package pango conflicts for:
# python-graphviz -> graphviz[version='>=2.46.1'] -> pango[version='>=1.42.4,<1.43.0a0|>=1.48.10,<1.49.0a0|>=1.48.9,<1.49.0a0|>=1.48.7,<1.49.0a0|>=1.48.5,<1.49.0a0|>=1.48.4,<1.49.0a0']
# graphviz -> pango[version='>=1.42.4,<1.43.0a0|>=1.48.10,<1.49.0a0|>=1.48.9,<1.49.0a0|>=1.48.7,<1.49.0a0|>=1.48.5,<1.49.0a0|>=1.48.4,<1.49.0a0']
#
# Package contextvars conflicts for:
# sniffio -> contextvars[version='>=2.1']
# anyio -> sniffio[version='>=1.1'] -> contextvars[version='>=2.1']
#
# Package importlib_metadata conflicts for:
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> importlib_metadata
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> importlib_metadata
# jsonschema -> importlib_metadata
# ipykernel -> argcomplete[version='>=1.12.3'] -> importlib_metadata[version='>=0.23,<4|>=0.23,<5']
#
# Package pytz conflicts for:
# jupyterlab_server -> babel -> pytz[version='>=2015.7']
# nltk=3.4 -> matplotlib -> pytz
# pandas=1.2 -> pytz[version='>=2017.2|>=2017.3']
# babel -> pytz[version='>=2015.7']
# matplotlib-base -> pytz
#
# Package fribidi conflicts for:
# pango -> fribidi[version='>=1.0.10,<2.0a0|>=1.0.9,<2.0a0']
# graphviz -> pango[version='>=1.48.10,<1.49.0a0'] -> fribidi[version='>=1.0.10,<2.0a0|>=1.0.9,<2.0a0']
#
# Package libprotobuf conflicts for:
# py-opencv -> libopencv==4.5.3=py38hb110498_5 -> libprotobuf[version='>=3.15.6,<3.16.0a0|>=3.15.8,<3.16.0a0|>=3.16.0,<3.17.0a0|>=3.18.1,<3.19.0a0']
# opencv=4.5 -> libopencv==4.5.3=py38hb110498_5 -> libprotobuf[version='>=3.15.6,<3.16.0a0|>=3.15.8,<3.16.0a0|>=3.16.0,<3.17.0a0|>=3.18.1,<3.19.0a0']
# libopencv -> libprotobuf[version='>=3.15.6,<3.16.0a0|>=3.15.8,<3.16.0a0|>=3.16.0,<3.17.0a0|>=3.18.1,<3.19.0a0']
#
# Package lerc conflicts for:
# pillow=8.1 -> libtiff[version='>=4.2.0,<5.0a0'] -> lerc[version='>=2.2.1,<3.0a0|>=3.0,<4.0a0']
# libgd -> libtiff[version='>=4.3.0,<5.0a0'] -> lerc[version='>=2.2.1,<3.0a0|>=3.0,<4.0a0']
# libopencv -> libtiff[version='>=4.3.0,<5.0a0'] -> lerc[version='>=2.2.1,<3.0a0|>=3.0,<4.0a0']
# libtiff -> lerc[version='>=2.2.1,<3.0a0|>=3.0,<4.0a0']
# openjpeg -> libtiff[version='>=4.2.0,<5.0a0'] -> lerc[version='>=2.2.1,<3.0a0|>=3.0,<4.0a0']
# lcms2 -> libtiff[version='>=4.2.0,<5.0a0'] -> lerc[version='>=2.2.1,<3.0a0|>=3.0,<4.0a0']
#
# Package pyqtchart conflicts for:
# matplotlib=3.3 -> pyqt -> pyqtchart==5.12[build='py36he2d232f_6|py38h885f38d_6|py39h415ef7b_6|py37hf2a7229_6|py36he2d232f_7|py39h415ef7b_7|py38h885f38d_7|py37hf2a7229_7|py39h415ef7b_5']
# qtconsole -> pyqt -> pyqtchart==5.12[build='py36he2d232f_6|py38h885f38d_6|py39h415ef7b_6|py37hf2a7229_6|py36he2d232f_7|py39h415ef7b_7|py38h885f38d_7|py37hf2a7229_7|py39h415ef7b_5']
# pyqt -> pyqtchart==5.12[build='py36he2d232f_6|py38h885f38d_6|py39h415ef7b_6|py37hf2a7229_6|py36he2d232f_7|py39h415ef7b_7|py38h885f38d_7|py37hf2a7229_7|py39h415ef7b_5']
#
# Package numpydoc conflicts for:
# ipython=7.20 -> jedi[version='>=0.10,<0.18'] -> numpydoc
# jedi -> numpydoc
#
# Package xorg-xproto conflicts for:
# xorg-libxext -> xorg-libx11[version='>=1.7.0,<2.0a0'] -> xorg-xproto
# xorg-libxpm -> xorg-xproto
# xorg-libxt -> xorg-xproto
# libgd -> xorg-libxpm -> xorg-xproto
# xorg-libx11 -> xorg-xproto
#
# Package xorg-kbproto conflicts for:
# xorg-libxpm -> xorg-libx11[version='>=1.7.0,<2.0a0'] -> xorg-kbproto
# xorg-libxext -> xorg-libx11[version='>=1.7.0,<2.0a0'] -> xorg-kbproto
# xorg-libxt -> xorg-kbproto
# xorg-libx11 -> xorg-kbproto
#
# Package lz4 conflicts for:
# libtiff -> zstd[version='>=1.3.7,<1.3.8.0a0'] -> lz4
# zstd -> lz4
#
# Package sniffio conflicts for:
# anyio -> sniffio[version='>=1.1']
# jupyter_server -> anyio[version='>=3.1.0,<4'] -> sniffio[version='>=1.1']
#
# Package pyopenssl conflicts for:
# urllib3 -> pyopenssl[version='>=0.14']
# requests-unixsocket -> urllib3[version='>=1.8,<2'] -> pyopenssl[version='>=0.14']
# requests=2.25 -> urllib3[version='>=1.21.1,<1.27'] -> pyopenssl[version='>=0.14']
# prometheus_client -> twisted -> pyopenssl[version='>=16.0.0']
#
# Package intel-openmp conflicts for:
# mkl -> intel-openmp=2021
# numpy=1.19 -> mkl[version='>=2019.4,<2021.0a0'] -> intel-openmp
# numexpr=2.7 -> mkl[version='>=2021.2.0,<2022.0a0'] -> intel-openmp=2021
# scipy=1.6 -> mkl[version='>=2021.2.0,<2022.0a0'] -> intel-openmp=2021
# libblas -> mkl==2021.4.0=h0e2418a_729 -> intel-openmp
#
# Package scandir conflicts for:
# testpath -> pathlib2 -> scandir
# importlib-metadata -> pathlib2 -> scandir
# pickleshare -> pathlib2 -> scandir
#
# Package parso conflicts for:
# ipython=7.20 -> jedi[version='>=0.16,<1.0'] -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0,<0.8.0|>=0.3.0,<0.8.0|>=0.5.0|>=0.5.0,<0.8.0|>=0.5.2,<0.8.0|>=0.7.0,<0.8.0|>=0.8.0,<0.9.0|>=0.7.0|>=0.5.2|>=0.3.0|>=0.2.0']
# jedi -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0,<0.8.0|>=0.3.0,<0.8.0|>=0.5.0,<0.8.0|>=0.5.2,<0.8.0|>=0.7.0,<0.8.0|>=0.8.0,<0.9.0|>=0.7.0|>=0.5.2|>=0.5.0|>=0.3.0|>=0.2.0']
#
# Package xorg-libxpm conflicts for:
# libgd -> xorg-libxpm
# graphviz -> libgd[version='>=2.3.3,<2.4.0a0'] -> xorg-libxpm
#
# Package liblapacke conflicts for:
# opencv=4.5 -> libopencv==4.5.3=py38hb110498_5 -> liblapacke[version='>=3.8.0,<4.0a0']
# libopencv -> liblapacke[version='>=3.8.0,<4.0.0a0|>=3.8.0,<4.0a0']
# py-opencv -> libopencv==4.5.3=py38hb110498_5 -> liblapacke[version='>=3.8.0,<4.0.0a0|>=3.8.0,<4.0a0']
#
# Package importlib_resources conflicts for:
# jsonschema -> importlib_resources
# jupyterlab_server -> jsonschema[version='>=3.0.1'] -> importlib_resources
# nbformat -> jsonschema[version='>=2.4,!=2.5.0'] -> importlib_resources
#
# Package pandoc conflicts for:
# notebook -> nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# jupyter=1.0 -> nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# jupyter_server -> nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
# nbconvert -> pandoc[version='>=1.12.1|>=1.12.1,<2.0.0']
#
# Package font-ttf-dejavu-sans-mono conflicts for:
# fonts-conda-ecosystem -> fonts-conda-forge -> font-ttf-dejavu-sans-mono
# fonts-conda-forge -> font-ttf-dejavu-sans-mono
#
# Package pypy3.6 conflicts for:
# brotlipy -> cffi[version='>=1.0.0'] -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*']
# cryptography -> cffi[version='>=1.12'] -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*']
# argon2-cffi -> cffi[version='>=1.0.0'] -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*']
# cffi -> pypy3.6[version='7.3.0.*|7.3.1.*|7.3.2.*|7.3.3.*']
#
# Package xorg-libxext conflicts for:
# libgd -> xorg-libxpm -> xorg-libxext=1.3
# xorg-libxpm -> xorg-libxext=1.3
#
# Package xorg-libxt conflicts for:
# libgd -> xorg-libxpm -> xorg-libxt[version='1.1.*|>=1.2.1,<2.0a0']
# xorg-libxpm -> xorg-libxt[version='1.1.*|>=1.2.1,<2.0a0']
# Note that strict channel priority may have removed packages required for satisfiability.
#
# C:\Users\bruno.gonzalez\Miniconda3\envs\tf2\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'raw.githubusercontent.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 'Code,Name\nAF,Afghanistan\nAX,Åland Islands\nAL,Albania\nDZ,Algeria\nAS,American Samoa\nAD,Andorra\nAO,Angola\nAI,Anguilla\nAQ,Antarctica\nAG,Antigua '

# %% [markdown]
# We then pass the data into `pandas` using a **buffer** instead of a **file descriptor**. A *buffer* is simply an array of memory and a *file descriptor* is a buffer that holds descriptive information about a file, but not the actual contents (i.e., the file's location, or where within the file a buffer is currently positioned).

# %%
import io
# read in request as if it was a file, but is really a buffer
pd.read_csv(filepath_or_buffer=io.StringIO(r.text))
# Out:
#     Code           Name
# 0     AF    Afghanistan
# 1     AX  Åland Islands
# 2     AL        Albania
# ..   ...            ...
# 246   YE          Yemen
# 247   ZM         Zambia
# 248   ZW       Zimbabwe
#
# [249 rows x 2 columns]

# %% [markdown]
# But what if the data requested is more complicated? What if the request is to a markup file, like HTML? Or an API?
# Many web APIs will return a JSON string that must be loaded into a Python object. How do we convert the JSON into something usable, like a `pandas` `DataFrame`?
#
# This is where `pandas` begins to truly shine. There are read functions in `pandas` for handling JSON and HTML. The function for handling HTML is implemented using more general libraries, meaning it actually attempts to handle XML structure first, before falling back on HTML parsing.
#
# Both parsing methods handle multi-indexing for nested markup and return lists of type `DataFrame` for HTML with multiple tables.

# %%
x = pd.read_html("http://www.multpl.com/s-p-500-historical-prices/table/by-month",
                 header=0,
                 skiprows=[1, 16],
                 index_col=0)
# NOTE: A list of `DataFrames` is returned
scrapedTable = x[0] 
scrapedTable
# Out:
#              Price Value
# Date
# Jul 1, 2018      2793.64
# Jun 1, 2018      2754.35
# May 1, 2018      2701.49
# ...                  ...
# Mar 1, 1871         4.61
# Feb 1, 1871         4.50
# Jan 1, 1871         4.44
#
# [1770 rows x 1 columns]

# %%
scrapedTable.columns
# Out:
# Index(['Price Value'], dtype='object')

# %% [markdown]
# But there are still restrictions on `read_html()`, such as only extracting `<table>` elements. What if another element type holds the data? Or, if the data is sporadically embedded?
#
# Thus, we'll cover how to extract data in general from these resources. But first a closer look at how our web resource contents are structured and organized.
#
# ## Web Page Contents
#
# We begin by refreshing ourselves on the structure of each data source resource type that might be encountered and their intended use. We'll go over the most common content types and their characteristics.
#
# ### HTML
#
# **Hyper Text Markup Language (HTML)** (WHATWG Apple, Google, Mozilla, Microsoft, 2018) has undergone many changes since its first inception. The intent behind HTML is for **presenting** structured content. It is quite literally a language for specifying the rules for displaying content. As of 2018, HTML is ***not*** valid XML. If you held a misconception that HTML was valid XML, then be at ease. That was the goal of their respective W3C standardization committees. This is what lead to XML-valid HTML spinning-off into the X/HTML standard. However, this standard's future is uncertain due to poor adoption.
#
# However, in general, it is simpler to assume HTML has the same structure as XML.
#
# ### XML
#
# XML consists of text, attributes, elements and special characters.
# ```
# <rootElement>
#   <childElement anAttribute="aValue">
#     aTextValue
#     <leafElement> anotherTextValue </leafElement>
#     <emptyleafElement withAnAttribute="anotherValue" />
#
#   </childElement>
# </rootElement>
# ```
# Unlike HTML, XML has ***no*** pre-defined elements. It is used to define other file formats. As such, XML has two ways to be evaluated.
#
# | Evaluation Type | Description |
# | --- | --- |
# | Validity | If the XML in question is well formed ***and*** also adheres to a definition or schema, like XHTML, then it is valid XML. |
# | Well Formedness | If elements are strictly nested as a tree format and there is no ambiguity as to what is an attribute, element, and text, then the file is well-formed XML. Definitions and schemas are not required. |
#
# Validity is determined by some sort of schema or data definition. This is usually in the form of a Data Type Definition (DTD) file or an XSchema file. Both allow for grammars to be defined for the XML file, but DTD defines a context-free grammar whereas XSchema defines a context-sensitive grammar (more expressive). In order for an XML document to be well-formed, special characters are necessary. For example, how do you express a mathematical inequality without introducing a new element?
#
# | Before special characters | After special characters |
# | --- | --- |
# | ```<anInEquality>1<x</anInEquality>``` | ```<anInEquality>1&lt;x</anInEquality>``` |
#
# If you've ever wondered why `&` throw errors when editing raw XML and HTML, now you know why. It is a character reserved for denoting special characters.
#
# **NOTE**: It is possible to parse malformed XML from a theoretical perspective. But, it's terribly inefficient and would slow your browser to a crawl if allowed in large one-page web applications. More precisely, XML can be parsed using a context-free grammar. HTML cannot be parsed in the same manner and requires a context-sensitive grammar, which is a more expressive grammar that requires more computation to execute its algorithm.
#
# See [Semantic Web Content](#Semantic-Web-Content) for more examples.
#
# ### CSS
#
# **Cascading Style Sheets (CSS)** (Mozilla and individual contributors, 2018) have a simple key-value pair like format. Properties are set to values for every instance of an element selection. Element selections (a.k.a. selectors) are simply used to match on branches of HTML or XML.
#
# ```
# <selector1> [, <selector2>, ...] {
#   property11: <value111> [, <value112>, ...];
#   ...
#   property1N: <value1N1> [, <value1N2>, ...];
# }
# ...
# <selectorM1> [, <selectorM2>, ...] {
#   propertyM1: <valueM11> [, <valueM12>, ...];
#   ...
#   propertyMN: <valueMN1> [, <valueMN2>, ...];
# }
# ```
# The following is an example snippet of CSS.
#
# ```
# body {
#   colour: blue;
#   background-color: yellow;
#   border: 1px solid black;
# }
# ```
#
# The snippet simply matches on a header element, similarly to how a *regular expression* might match on a substring. Upon a successful match, it does the following:
#
# * Sets the element colour property to blue
# * Sets the background colour for the displayed text to yellow
# * Sets a 1 pixel thick solid (as opposed to broken or dashed) black border surrounding the element's displayed text
#
# Afterwards, the rule continues to attempt matching on another element of the same type farther down in the document.
#
# At this point, you might wonder why CSS exists. Isn't it doing the same thing as HTML in deciding how a page will be presented? To an extent, this is the case. However, XML with CSS is not capable of all the display options as HTML is alone. HTML actually has a superset of capabilities. However, CSS does allow for different CSS style sheets to be used for different display mediums (i.e., phone vs. tablet vs. computer vs. TV vs. projector, etc.) in a clean and modular fashion. The equivalent of this in one HTML page would be a mess of style injections for different elements, and prone to issues depending on browser support.
#
# The overlap of CSS with HTML brings forth the primary motivation for moving away from HTML. HTML is not maintainable for complex logic in an environment where web browsers may not support standards consistently. In terms of web scraping, CSS forces a decoupling of content and style, making the it easier to scrape and clean content.
#
# ### JavaScript
#
# JavaScript is a programming language which enables interactive web content. It is often used for communicating with web applications and acts as the primary programming layer for all client-side requests. Javascript enables content and the display of pages to change during the time a webpage is viewed. Its main use is for enabling User Interface logic, but the language is a full fledged programming language and has the same general capabilities as any other programming language.
#
# Javascript is more standardized in terms of client-side web applications. In a browser environment, Javascript makes use of the **Document Object Model (DOM)**. The DOM is a data structure that represents the current state of the web page content, and contains all information and programming event logic associated with CSS and HTML/XML (i.e., url, window dimensions, html used for rendering, HTML currently displaying, previously visited URL, etc.). To put it in simpler terms, the CSS and HTML/XML/XHTML content are all placed by the web browser into the DOM, which the browser then manipulates using Javascript. It would be accurate to say the DOM is the active state of the web page. With respect to the DOM, Javascript manipulations are forced to only trigger event listeners (like a mouse click) attached on elements, and then run a handler/function for reacting to listened events (like the effect of clicking a button).
#
# Events are always listened to in the direction from the triggered element up to the root element. Events are handled in the reverse direction. These are event handlers.
#
# For our purposes, we are more interested in how JavaScript is used for communicating with web applications, as this is the use case for querying data through a web API. Since requests between servers and clients are simply packets of text or binary information, Javascript can be directly injected into the content of either a request or a response. Since the browser already uses the DOM to represent all client-side data, it is often easier to use JavaScript values and objects directly to manipulate it. Hence, JavaScript Object Notation (JSON) is used to transmit message content, instead of some special messaging protocol. The primary motivation for letting the server send injectable-code (usually considered a security risk) as data is simple. The client already trusts the server, otherwise it wouldn't have connected to the URL. This is a good assumption if your web browser is its own separate process and cannot manipulate your computer's operating system.
#
#
# JSON format is based on key-value pairs similar to CSS. However, rather than supporting just simple key-value pairs, JavaScript values can be arrays and objects, and not only primary values, like strings, booleans, and numbers.
#
# ```
# {
#   "property1": "stringValue",
#   "property2": true,
#   "property3": 0,
#   "property4": {
#     "embeddedJSONProperty": "embeddedJSONValue",
#   },
#   "property5": [
#     {
#       "arrayOfEmbeddedJSONProperty1": "value1",
#     },
#     {
#       "arrayOfEmbeddedJSONProperty2": "value2",
#     }
#   ],
#   "property6": [],
#   "property7": null
# }
# ```
#
# See [Semantic Web Content](#Semantic-Web-Content) for more examples.
#
# ### Semantic Web Content
#
# Semantic web markup is used to describe Entities. Entities can have the following attached to them:
#
# * Relationships
# * Attributes
# * Types
#
# This is very similar to a database. However, semantic web markup is meant for describing resources so as to make data queryable. The major file formats used to describe semantic web resources are in the following table:
#
# | Format | Description | Example |
# | --- | --- | --- |
# | Resource Description Framework (RDF) | RDF is the most minimal format. RDF is an XML format which makes full use of XSchema type values. It allows class relationships, and instance relationships to be defined along with properties and attributes. | see 1 |
# | Web Ontology Language (OWL) | OWL is more expressive than RDF. OWL is an XML format which makes full use of XSchema type values. OWL is actually Turing-complete in terms of expressiveness. Additionally, unlike RDF, OWL has an all encompassing class, a null class. | see 2 |
# | Turtle (TTL) | TTL is a non tabular record format. It is actually just a different way of writing data. TTL is not a document type like XML or HTML. In fact, it is usually defined using either RDF or OWL. | see 3 |
# | N-Triple | N-Triple is a tabular record format. It is a different way of writing data. N-Triple is not a document type like XML or HTML. In fact, it is usually defined using either RDF or OWL. | see 4 |
# | JavaScript Object Notation for Linked Data (JSON-LD) | Since JSON has a tree structure like XML, RDF and OWL data is also expressible. The only difference is that a `type` and `id ` must be specified for each resource. | see 5 |

# %% [markdown]
# Here are are some examples of these formats:
#
# 1.
# ```<?xml version="1.0" encoding="utf-8"?>
# <rdf:RDF xmlns:contact="http://www.w3.org/2000/10/swap/pim/contact#" xmlns:eric="http://www.w3.org/People/EM/contact#" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#   <rdf:Description rdf:about="http://www.w3.org/People/EM/contact#me">
#     <contact:fullName>Eric Miller</contact:fullName>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://www.w3.org/People/EM/contact#me">
#     <contact:mailbox rdf:resource="mailto:e.miller123(at)example"/>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://www.w3.org/People/EM/contact#me">
#     <contact:personalTitle>Dr.</contact:personalTitle>
#   </rdf:Description>
#   <rdf:Description rdf:about="http://www.w3.org/People/EM/contact#me">
#     <rdf:type rdf:resource="http://www.w3.org/2000/10/swap/pim/contact#Person"/>
#   </rdf:Description>
# </rdf:RDF>```
#
# 2.
# ```<rdf:RDF ...> <owl:Ontology rdf:about=""/> <owl:Class rdf:about="#Tea"/> </rdf:RDF>```
#
# \cite{2018a}
#
# 3.
# ```@prefix eric:    <http://www.w3.org/People/EM/contact#> .
# @prefix contact: <http://www.w3.org/2000/10/swap/pim/contact#> .
# @prefix rdf:     <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# eric:me contact:fullName "Eric Miller" .
# eric:me contact:mailbox <mailto:e.miller123(at)example> .
# eric:me contact:personalTitle "Dr." .
# eric:me rdf:type contact:Person .```
#
# 4.
# ```<http://www.w3.org/People/EM/contact#me> <http://www.w3.org/2000/10/swap/pim/contact#fullName> "Eric Miller" .
# <http://www.w3.org/People/EM/contact#me> <http://www.w3.org/2000/10/swap/pim/contact#mailbox> <mailto:e.miller123(at)example> .
# <http://www.w3.org/People/EM/contact#me> <http://www.w3.org/2000/10/swap/pim/contact#personalTitle> "Dr." .
# <http://www.w3.org/People/EM/contact#me> <http://www.w3.org/1999/02/22-rdf-syntax-ns#type> <http://www.w3.org/2000/10/swap/pim/contact#Person> .```
#
# 5.
# ``` {"@context": {
#     "name": "http://xmlns.com/foaf/0.1/name",
#     "homepage": {
#       "@id": "http://xmlns.com/foaf/0.1/workplaceHomepage",
#       "@type": "@id"
#     },
#     "Person": "http://xmlns.com/foaf/0.1/Person"
#   },
#   "@id": "http://me.example.com",
#   "@type": "Person",
#   "name": "John Smith",
#   "homepage": "http://www.example.com/"}```
#
# These numerous formats are the consequence of enabling different data sources to be linked, regardless of format. But, the important thing to remember is that the semantic markup can contain data, or schema typing information, or complex value definitions. As such, the semantic web is only as useful as the browser makes it. In the case of semantic web sources, they are most useful when scraping data without having to clean it.
#
# ### Images
#
# Images generally come in two formats:
#
# | General Formats | Description |
# | --- | --- |
# | Vector | This format stores all points and lines as geometric data. As a result, scaling the image does not lead to a loss of resolution. Instead the image is simply re-rendered. |
# | Raster | This format stores all pixels individually as binary data. As a result, the image loses resolution as it is scaled up. However, it doesn't require a fresh computation for every rescale. |
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/aa/VectorBitmapExample.svg" alt="Vector vs Bitmap" style="width: 200px;"/>
#  Image Source: "_File:vectorbitmapexample.svg --- wikimedia commons, the free media repository_",  2018.  [online](https://commons.wikimedia.org/w/index.php?title=File:VectorBitmapExample.svg&oldid=294435857)
#
# In general, these images can be stored in any file format, but with the shift towards the semantic web, more vector formats tend to be XML based. The reasoning is actually related to standardization and committees spinning off from the W3C. In particular, there is a specific push by the Web3D Consortium (Web 3D Consortium, 2018) to be able to render 3D data and visualizations in a way that 3D models can be re-used by Computer Assisted Design (CAD) programs. For example, a geographic map is actually a 2D projection of a 3D model of the earth. As such, if the vector image of a map also contains all this data and renders from scratch starting with the 3D data, then this image can be reused by other geographers for other maps.
#
#
# While this might seem like a rare use case, the cost to make maps using satellite raster images is quite expensive depending on the resolution. Similarly, the model of the earth is not fixed. As a result, there is a demand to be able to reuse information, even if it isn't raw data but models interpreting the data, such as 3D mathematical models of the earth.
#
# ### Micro-formats
#
# Micro-formats are loosely defined, but in general they are formats embedded in other resources.
# Let us consider Wikipedia. Many pages in Wikipedia have info-boxes via table summarizations (resource description framework, nd.). These table summarizations, though defined and rendered in HTML, are constrained by the attributes used to identify them. And this constraint is consistent across the entirety of Wikipedia, because they are actually standardized and enforced by the authors themselves. Their intended use is to provide hooks into content to extract data. As such, the micro-formats are very minimal and only require annotating class information and relationships between classes onto the format.
#
# | Example of Data | Example of Data with Micro-format |
# | --- | --- |
# | ```<ul><li>Joe Doe</li><li>The Example Company</li><li>604-555-1234</li><li><a href="http://example.com/">http://example.com/</a></li></ul>``` | ```<ul class="vcard"><li class="fn">Joe Doe</li><li class="org">The Example Company</li><li class="tel">604-555-1234</li><li><a class="url" href="http://example.com/">http://example.com/</a></li></ul>``` |
#
#
# The use of this information is usually for easier extraction and to link up with semantic web data. An example of this is GeoNames (GeoNames community, 2013) which extracts from multiple sources, but makes use of the micro-formats for all place-taxonomy Wikipedia pages that also have geographic coordinate systems. As a result the data (extracted from publicly available resources) is freely available.
#
# As of 2018, Micro-formats have a standard being recommended as part of the HTML standard.

# %% [markdown]
# **End of Part 1**
#
# This notebook makes up one part of this module. Now that you have completed this part, please proceed to the next notebook in this module.
# If you have any questions, please reach out to your peers using the discussion boards. If you and your peers are unable to come to a suitable conclusion, do not hesitate to reach out to your instructor on the designated discussion board.

# %% [markdown]
# **Links**
#
# * http://blog.miguelgrinberg.com/post/easy-web-scraping-with-python
#   * About scraping using other python libraries, as well as crawling entire websites.
# * http://scrapy.org/
#   * About writing scrapers as configeration files via scrapy.
# * https://docs.python.org/2/library/urllib2.html
#   * documentation for urlib2 library
# * http://docs.python-requests.org/en/latest/
# * The Absolute Minimum Every Software Developer Absolutely, Positively Must Know About Unicode and Character Sets (No Excuses!)
#   * https://www.joelonsoftware.com/2003/10/08/the-absolute-minimum-every-software-developer-absolutely-positively-must-know-about-unicode-and-character-sets-no-excuses/
# * http://import.io
#   * a web-based platform for extracting data from websites without writing any code.
# * http://www.crummy.com/software/BeautifulSoup/
#   * popular alternative to lxml for web/screen scraping
# * http://pbpython.com/web-scraping-mn-budget.html
#   * Tutorial using BeautifulSoup with requests library, pandas, numpy and mathplotlib
# * Python Regular Expressions Cheat Sheet
#   * https://pycon2016.regex.training/cheat-sheet

# %% [markdown]
# # References
#
# Application programming interface, nd. Wikipedia, the free encyclopedia, retrieved Aug 20, 2018.  [online](https://en.wikipedia.org/w/index.php?title=Application_programming_interface&oldid=848903375)
#
# Bos, B. (2018). ``_Web style sheets_''.  [online](https://www.w3.org/Style/)
#
# Bray, 2017. The javascript object notation data interchange format. [online](https://www.rfc-editor.org/rfc/rfc8259.txt)GeoNames community, 2013. GeoNames. [online](http://www.geonames.org/)
#
# C. S. S. working group, 2018. ``_Cascading style sheets_'', Retrieved July 2018.  [online](https://www.w3.org/Style/CSS/)
#
# Hazaël-Massieux, D. (2016) W3C. ``_Javascript web apis - w3c_''.  [online](https://www.w3.org/standards/webdesign/script)
#
# Help:infobox, nd. Wikipedia, the free encyclopedia, retrieved Aug 20, 2018.  [online](https://en.wikipedia.org/wiki/Help:Infobox)
#
# Json-ld, nd. Wikipedia, the free encyclopedia, retrieved Aug 20, 2018.  [online](https://en.wikipedia.org/w/index.php?title=JSON-LD&oldid=841694454)
#
# McKinney, W. (2017). Python for data analysis, Data wrangling with pandas, numpy, and ipython (2nd edition).
#
# Microservices, nd. Wikipedia, the free encyclopedia, retrieved Aug 20, 2018.  [online](https://en.wikipedia.org/w/index.php?title=Microservices&oldid=848990555)
#
# Motto, 2018. Todd Motto, Github - toddmotto/public-apis: a collective list of public json apis for use in web development. Retrieved July 2018. [online](https://github.com/toddmotto/public-apis)
#
# Mozilla and individual contributors, 2018. ``_CSS basics_''.  [online](https://developer.mozilla.org/en-US/docs/Learn/Getting_started_with_the_web/CSS_basics)
#
# Resource description framework, nd. Wikipedia, the free encyclopedia, retrieved Aug 20, 2018.  [online](https://en.wikipedia.org/w/index.php?title=Resource_Description_Framework&oldid=836549456)
#
# Schema.org community, (2018). ``_Schema.org_''.  [online](https://schema.org/)
#
# Semantic Web, nd. Wikipedia, the free encyclopedia, retrieved Aug 20, 2018.  [online](https://en.wikipedia.org/w/index.php?title=Semantic_Web&oldid=847416702)
#
# Software as a service, nd. Wikipedia, the free encyclopedia, retrieved Aug 20, 2018.  [online](https://en.wikipedia.org/w/index.php?title=Software_as_a_service&oldid=845520263)
#
# W3C Community, 2016. X. M. L. Core Working Group, Extensible markup language (xml). [online](https://www.w3.org/XML/Core/)
#
# W3C Community, 2018. W3C. Web Platform Working Group, ``_W3c html_'' [online](https://www.w3.org/html/)
#
# Web 2.0, nd. Wikipedia, the free encyclopedia, retrieved Aug 20, 2018.  [online](https://en.wikipedia.org/wiki/Web_2.0)
#
# Web3D Consortium, 2018. Web3d consortium | open standards for real-time 3d communication.  [online](http://www.web3d.org/)
#
# Web ontology language, nd. Wikipedia, the free encyclopedia, retrieved Aug 20, 2018.  [online](https://en.wikipedia.org/w/index.php?title=Web_Ontology_Language&oldid=836282096)
#
# WHATWG (Apple, Google, Mozilla, Microsoft), 2018. Html living standard, 2018.  [online](http://www.whatwg.org/specs/web-apps/current-work/multipage/)
#
# Wiki, nd. Wikipedia, the free encyclopedia, retrieved Aug 20, 2018.  [online](https://en.wikipedia.org/w/index.php?title=Wiki&oldid=848864746)
#
# World wide web consortium (w3c),  2018.  [online](https://www.w3.org/)
